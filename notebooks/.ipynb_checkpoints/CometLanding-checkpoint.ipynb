# %%
import pandas as pd
import math
import json
import re
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from PIL import Image
import datetime as dt
import networkx as nx
from matplotlib import pylab
import sys
import unittest
import time
import datetime
import seaborn as sns
from matplotlib.widgets import Button

# %%
sys.path.append('../code')

# %%
import generateGraphs as gg
import fixdata as fd

# %%
df = pd.read_csv("../data/CometLandingFixed.csv",
                 dtype={"id_str": str, "in_reply_to_user_id_str": str, "from_user_id_str": str,
                        "in_reply_to_status_id_str": str, "user_followers_count": "Int64",
                        "user_friends_count": "Int64", "geo_coordinates": str}, parse_dates=['created_at']
                 )

# %%
# to be removed if fixdata.py works fine
fd.create_retweet_columns(df)

# %%
df
# Out:
#                    id_str        from_user  \
# 0      540930409279008768  amika0078788556
# 1      540930042700656640   ChrisDMarshall
# 2      540929998388211713         MHuuskoL
# 3      540929346878599168  SaraGomezAranci
# 4      540929229052203008          CBCDay6
# ...                   ...              ...
# 77302  532460149084930049     ABForScience
# 77303  532460148451581952           atieyK
# 77304  532460148254470144           j0nny5
# 77305  532460148238090240          nsentse
# 77306  532460147764125696          grery92
#
#                                                     text  \
# 0      RT @VersaTechnology: Congratulations @Philae20...
# 1      CometWatch 2 December Â» Rosetta - ESA's comet...
# 2      RT @EUCouncil: After the #CometLanding - Astro...
# 3      RT @EUCouncil: After the #CometLanding - Astro...
# 4      RT @shaunmajumder: Feels good to be the @CBCDa...
# ...                                                  ...
# 77302  This means  that the actual landing will be ar...
# 77303  RT @ObservingSpace: Weâ€™ve been waiting 10 ye...
# 77304  RT @maxplanckpress: Accomazzo (flight director...
# 77305                   7 hours of waiting #CometLanding
# 77306  RT @dsdanyds: TopTrendIT: TT ITALIA 09:59\r\n1...
#
#                      created_at geo_coordinates user_lang  \
# 0     2014-12-05 18:07:14+00:00             NaN        en
# 1     2014-12-05 18:05:46+00:00             NaN        en
# 2     2014-12-05 18:05:36+00:00             NaN        en
# 3     2014-12-05 18:03:00+00:00             NaN        fr
# 4     2014-12-05 18:02:32+00:00             NaN        en
# ...                         ...             ...       ...
# 77302 2014-11-12 09:09:26+00:00             NaN        en
# 77303 2014-11-12 09:09:26+00:00             NaN        en
# 77304 2014-11-12 09:09:26+00:00             NaN        en
# 77305 2014-11-12 09:09:26+00:00             NaN        en
# 77306 2014-11-12 09:09:26+00:00             NaN        it
#
#       in_reply_to_user_id_str in_reply_to_screen_name from_user_id_str  \
# 0                         NaN                     NaN       1297570116
# 1                         NaN                     NaN         42201214
# 2                         NaN                     NaN        574434762
# 3                         NaN                     NaN       1057356487
# 4                         NaN                     NaN        177276897
# ...                       ...                     ...              ...
# 77302                     NaN                     NaN       2333122519
# 77303                     NaN                     NaN         58303715
# 77304                     NaN                     NaN         17914863
# 77305                     NaN                     NaN         20434005
# 77306                     NaN                     NaN        487827577
#
#       in_reply_to_status_id_str  ...  \
# 0                           NaN  ...
# 1                           NaN  ...
# 2                           NaN  ...
# 3                           NaN  ...
# 4                           NaN  ...
# ...                         ...  ...
# 77302                       NaN  ...
# 77303                       NaN  ...
# 77304                       NaN  ...
# 77305                       NaN  ...
# 77306                       NaN  ...
#
#                                        profile_image_url user_followers_count  \
# 0      http://pbs.twimg.com/profile_images/3555068293...                  425
# 1      http://pbs.twimg.com/profile_images/228087980/...                  347
# 2      http://pbs.twimg.com/profile_images/4973510588...                  215
# 3      http://pbs.twimg.com/profile_images/5391705804...                  741
# 4      http://pbs.twimg.com/profile_images/4590694303...                 4331
# ...                                                  ...                  ...
# 77302  http://pbs.twimg.com/profile_images/4320695593...                  155
# 77303  http://pbs.twimg.com/profile_images/5057311637...                  354
# 77304  http://pbs.twimg.com/profile_images/89991673/j...                   92
# 77305  http://pbs.twimg.com/profile_images/3693655850...                  200
# 77306  http://pbs.twimg.com/profile_images/3788000004...                  194
#
#        user_friends_count                                         status_url  \
# 0                     113  http://twitter.com/amika0078788556/statuses/54...
# 1                    1286  http://twitter.com/ChrisDMarshall/statuses/540...
# 2                     310  http://twitter.com/MHuuskoL/statuses/540929998...
# 3                     310  http://twitter.com/SaraGomezAranci/statuses/54...
# 4                    2098  http://twitter.com/CBCDay6/statuses/5409292290...
# ...                   ...                                                ...
# 77302                 212  http://twitter.com/ABForScience/statuses/53246...
# 77303                1088  http://twitter.com/atieyK/statuses/53246014845...
# 77304                  63  http://twitter.com/j0nny5/statuses/53246014825...
# 77305                 267  http://twitter.com/nsentse/statuses/5324601482...
# 77306                 403  http://twitter.com/grery92/statuses/5324601477...
#
#                                             entities_str  \
# 0      {"hashtags":[{"text":"Philae","indices":[49,56...
# 1      {"hashtags":[{"text":"CometLanding","indices":...
# 2      {"hashtags":[{"text":"CometLanding","indices":...
# 3      {"hashtags":[{"text":"CometLanding","indices":...
# 4      {"hashtags":[{"text":"MiniMansbridge","indices...
# ...                                                  ...
# 77302  {"hashtags":[{"text":"CometLanding","indices":...
# 77303  {"hashtags":[{"text":"cometlanding","indices":...
# 77304  {"hashtags":[{"text":"CometLanding","indices":...
# 77305  {"hashtags":[{"text":"CometLanding","indices":...
# 77306  {"hashtags":[{"text":"GUERRIERO","indices":[44...
#
#              specific_applications             applications  \
# 0               Twitter Web Client                  Twitter
# 1             Twitter for Websites                  Twitter
# 2                 Twitter for iPad                  Twitter
# 3               Twitter for iPhone                  Twitter
# 4              Twitter for Android                  Twitter
# ...                            ...                      ...
# 77302      TweetCaster for Android  TweetCaster for Android
# 77303  Twitter for Android Tablets                  Twitter
# 77304           Twitter Web Client                  Twitter
# 77305           Twitter for iPhone                  Twitter
# 77306          Twitter for Android                  Twitter
#
#       retweet_user_id_str retweet_user_screen_name   retweet_user_name
# 0                30264992          VersaTechnology    Versa Technology
# 1                     NaN                      NaN                 NaN
# 2               206717989                EUCouncil          EU Council
# 3               206717989                EUCouncil          EU Council
# 4                17680518            shaunmajumder      Shaun Majumder
# ...                   ...                      ...                 ...
# 77302                 NaN                      NaN                 NaN
# 77303          1041442471           ObservingSpace     Observing Space
# 77304           205195655           maxplanckpress  Max Planck Society
# 77305                 NaN                      NaN                 NaN
# 77306           406884842                 dsdanyds      daniela sforza
#
# [77307 rows x 21 columns]

# %% [markdown]
# Data Cleaning: <br>
# The duplicated records are first removed.  Then, records without any of the following essetial fields (ie. value = Nan) are also removed: id_str (Tweet ID), from_user_id_str (User ID), text (Tweet text), entities_str (information including hashtags used, users mentioned and used URL).  These fields are considered essential for analysing the dataset that we decide to remove records without any of these fields as they will not be usable for analysis.  The data are also filtered so that only tweets between 2014-11-12 and 2014-12-05 inclusively remain.  Additional filtering is also done to make sure all tweets in the dataset contain the hashtag "CometLanding" of any case as this should be the criteria of the tweets being in this dataset.

# %% [markdown]
# New Fields: <br>
# New columns "specific_applications" and "applications" are added to store the application used for sending the tweet. "specific_applications" treated the same application for different devices as distinct applications (eg. Twitter for iPhone is different from Twitter for Android) while "applications" generalize them as the same application (eg. Twitter for iPhone and Twitter for Android are stored as Twitter).  There are also new columns added for information related to the user being retweeted: "retweet_user_id_str" (Retweeted User ID), "retweet_user_screen_name" (Retweeted User screen name), "retweet_user_name" (Retweeted User username).

# %% [markdown]
# Refine ID: <br>
# "id_str" is refined with the "status_url".  Specifically, its value is replaced with the last 18 characters of "status_url".  This decision starts from the observation that the original values of "id_str" of 18 digits are not unique ie. there are some tweets that share the same ID, which should not be the case.  Then, it is observed that the URL in "status_url" always end with also 18 digits, and the first 15 digits are always the same as that of "id_str".  In addition to the fact the the last 3 digits of "id_str" are always zeroed, it is concluded that the original value of "id_str" are merely the 15 digits prefix of the actual Tweet ID with the last 3 zeroed, and that the one in "status_url" is the actual, full Tweet ID.  This conclusion is also supported by the fact that all values in "status_url" are unique.  Thus, the substitution is made for tweets with non-empty "status_url" field, or else "id_str" field remains the same.

# %%
type(df["created_at"])
# Out:
# pandas.core.series.Series

# %%
len(df)
# Out:
# 77307

# %%
df.dtypes
# Out:
# id_str                                    object
# from_user                                 object
# text                                      object
# created_at                   datetime64[ns, UTC]
# geo_coordinates                           object
# user_lang                                 object
# in_reply_to_user_id_str                   object
# in_reply_to_screen_name                   object
# from_user_id_str                          object
# in_reply_to_status_id_str                 object
# source                                    object
# profile_image_url                         object
# user_followers_count                       Int64
# user_friends_count                         Int64
# status_url                                object
# entities_str                              object
# specific_applications                     object
# applications                              object
# dtype: object

# %%
reply_df = df[["in_reply_to_user_id_str",
               "in_reply_to_screen_name", "in_reply_to_status_id_str"]]

# %%
reply_df
# Out:
#       in_reply_to_user_id_str in_reply_to_screen_name  \
# 0                         NaN                     NaN
# 1                         NaN                     NaN
# 2                         NaN                     NaN
# 3                         NaN                     NaN
# 4                         NaN                     NaN
# ...                       ...                     ...
# 77302                     NaN                     NaN
# 77303                     NaN                     NaN
# 77304                     NaN                     NaN
# 77305                     NaN                     NaN
# 77306                     NaN                     NaN
#
#       in_reply_to_status_id_str
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 77302                       NaN
# 77303                       NaN
# 77304                       NaN
# 77305                       NaN
# 77306                       NaN
#
# [77307 rows x 3 columns]

# %%
# reply
def isreply(tweet):
    if not pd.isna(tweet):
        print(tweet)

# %%
total_replies = df[pd.notna(df["in_reply_to_user_id_str"])]  # replies

# %%
len(total_replies.index)  # amount of replies
# Out:
# 1724

# %%
# print all replies
replies = reply_df["in_reply_to_user_id_str"].map(isreply)
# Out:
# 11348282
# 19442947
# 253536357
# 253536357
# 64643056
# 33602654
# 1691515789
# 19402238
# 529722897
# 2294593507
# 41333964
# 253536357
# 66162716
# 65479951
# 208442526
# 32480474
# 7109302
# 2277987787
# 123440736
# 29792943
# 190943447
# 1325162114
# 1372577988
# 59066390
# 208442526
# 133247890
# 17384099
# 1176805206
# 2097571
# 208442526
# 253536357
# 2860590142
# 208442526
# 208442526
# 253536357
# 746140256
# 2860590142
# 32480474
# 324096530
# 253536357
# 21168624
# 253536357
# 92762823
# 208442526
# 1618590241
# 299545425
# 65479951
# 208442526
# 368915372
# 253536357
# 15495464
# 75887588
# 237216383
# 20401442
# 2270640056
# 20836794
# 850229958
# 25188886
# 253536357
# 198494684
# 76906335
# 253536357
# 57880896
# 317313520
# 20521159
# 208442526
# 253536357
# 2860590142
# 253508578
# 19653925
# 5402612
# 2320839829
# 208442526
# 253536357
# 208442526
# 208442526
# 841386619
# 274360107
# 393608992
# 253536357
# 21436960
# 528937116
# 208442526
# 11348282
# 253536357
# 500543472
# 128622564
# 208442526
# 208442526
# 79414915
# 253536357
# 1397978796
# 607137149
# 17384099
# 21436960
# 246795139
# 253536357
# 21436960
# 87416722
# 208442526
# 7996082
# 154229540
# 253536357
# 253536357
# 130177606
# 208442526
# 208442526
# 208442526
# 5402612
# 489482364
# 14807898
# 19125016
# 253536357
# 253536357
# 73101705
# 557719049
# 17384099
# 234273955
# 558793908
# 253536357
# 253536357
# 20836794
# 17384099
# 208442526
# 253536357
# 19766517
# 1168903477
# 21436960
# 253536357
# 253536357
# 682463
# 208442526
# 21436960
# 21436960
# 253536357
# 253536357
# 253536357
# 21436960
# 17384099
# 105554801
# 208442526
# 21436960
# 1510299787
# 2599011275
# 21436960
# 208442526
# 253536357
# 36886619
# 65479951
# 141628169
# 24389399
# 274663230
# 253536357
# 14228893
# 334738427
# 33773592
# 123635115
# 516448186
# 208442526
# 253536357
# 208442526
# 253536357
# 208442526
# 166683513
# 2212541899
# 2868682372
# 18061411
# 56183928
# 253536357
# 275686563
# 5402612

# %%
def getAllReplies(df):
    total_replies_df = df[pd.notna(df['in_reply_to_user_id_str'])]
    return total_replies_df

def getAllRetweets(df):
    nan_reply_user_id_df = df[pd.isna(df['in_reply_to_user_id_str'])]
    retweet_only_df = nan_reply_user_id_df[nan_reply_user_id_df['text'].apply(
        lambda x: True if re.search("^RT @.*", x)else False)]
    return retweet_only_df

def getAllTweets(df):
    nan_reply_user_id_df = df[pd.isna(df['in_reply_to_user_id_str'])]
    tweet_only_df = nan_reply_user_id_df[nan_reply_user_id_df['text'].apply(
        lambda x: False if re.search("^RT @.*", x)else True)]
    return tweet_only_df
    
total_replies_df = getAllReplies(df)

retweet_only_df = getAllRetweets(df)

tweet_only_df = getAllTweets(df)

# %%
total_replies_df
# Out:
#                    id_str       from_user  \
# 29     540896030628532224  einfachbloggen
# 64     540776048414031872       gwittrapp
# 108    540556460443594752    acolliver615
# 127    540488420062429185     WillemelliW
# 128    540482901624647682      Chapuler38
# ...                   ...             ...
# 76974  532460309639094272   whereisyvette
# 77198  532460192571883520        arrayson
# 77250  532460171843629056        drfarres
# 77254  532460170513625088           cocoy
# 77269  532460161126789120       Del_Alpha
#
#                                                     text  \
# 29     Congrats MT @NASA: #Orion's flying free for th...
# 64     @nathanbroon last month you tagged 10 tweets w...
# 108    @ESA_Rosetta keep sending pictures, they're ep...
# 127    @ESA_Rosetta kan een puntje zuigen aan de vers...
# 128    @RT_com @NASA Looking for miracles? Then #orio...
# ...                                                  ...
# 76974  @purplefroglet also FYI I am bringing prosecco...
# 77198  â€œ@charlieowen4: Seven hours until Philae lan...
# 77250  @ESA_Rosetta congratulatins for the separation...
# 77254  â€œ@verge: Rosetta's probe just began its prec...
# 77269  RT @BBCBreaking @Philae2014 lander released fr...
#
#                      created_at              geo_coordinates user_lang  \
# 29    2014-12-05 15:50:37+00:00                          NaN        de
# 64    2014-12-05 07:53:51+00:00                          NaN     en-gb
# 108   2014-12-04 17:21:17+00:00  loc: 39.2076777,-83.6107315        en
# 127   2014-12-04 12:50:55+00:00                          NaN        en
# 128   2014-12-04 12:29:00+00:00                          NaN        en
# ...                         ...                          ...       ...
# 76974 2014-11-12 09:10:05+00:00                          NaN        en
# 77198 2014-11-12 09:09:37+00:00                          NaN     en-gb
# 77250 2014-11-12 09:09:32+00:00                          NaN        ca
# 77254 2014-11-12 09:09:31+00:00                          NaN        en
# 77269 2014-11-12 09:09:29+00:00                          NaN        en
#
#       in_reply_to_user_id_str in_reply_to_screen_name from_user_id_str  \
# 29                   11348282                    NASA        398268735
# 64                   19442947             nathanbroon       1673116172
# 108                 253536357             ESA_Rosetta       2260971996
# 127                 253536357             ESA_Rosetta       1201626438
# 128                  64643056                  RT_com        205378951
# ...                       ...                     ...              ...
# 76974                18061411           purplefroglet        123421220
# 77198                56183928            charlieowen4       1912388480
# 77250               253536357             ESA_Rosetta        190801607
# 77254               275686563                   verge          1147491
# 77269                 5402612             BBCBreaking         48927755
#
#       in_reply_to_status_id_str  \
# 29           540891938275467000
# 64                          NaN
# 108          540554322535534000
# 127                         NaN
# 128          540481604666556000
# ...                         ...
# 76974        532459942679429000
# 77198        532459997771202000
# 77250        532459086462615000
# 77254        532459464155484000
# 77269        532458951678640000
#
#                                                   source  \
# 29     <a href="http://twitter.com/download/iphone" r...
# 64     <a href="http://gwittr.com" rel="nofollow">Gwi...
# 108    <a href="http://twitter.com/download/android" ...
# 127    <a href="http://twitter.com" rel="nofollow">Tw...
# 128    <a href="http://twitter.com/download/iphone" r...
# ...                                                  ...
# 76974  <a href="http://twitter.com/download/iphone" r...
# 77198  <a href="http://twitter.com/download/iphone" r...
# 77250  <a href="http://twitter.com/download/iphone" r...
# 77254  <a href="http://itunes.apple.com/us/app/twitte...
# 77269  <a href="http://twitter.com" rel="nofollow">Tw...
#
#                                        profile_image_url  \
# 29     http://pbs.twimg.com/profile_images/5098209126...
# 64     http://pbs.twimg.com/profile_images/3788000004...
# 108    http://pbs.twimg.com/profile_images/5329781788...
# 127    http://pbs.twimg.com/profile_images/3283427317...
# 128    http://pbs.twimg.com/profile_images/4434806916...
# ...                                                  ...
# 76974  http://pbs.twimg.com/profile_images/980798471/...
# 77198  http://pbs.twimg.com/profile_images/4887538097...
# 77250  http://pbs.twimg.com/profile_images/2312825800...
# 77254  http://pbs.twimg.com/profile_images/4849003519...
# 77269  http://pbs.twimg.com/profile_images/4270082295...
#
#        user_followers_count  user_friends_count  \
# 29                      191                 199
# 64                      139                 531
# 108                      56                 364
# 127                      29                 113
# 128                     466                 477
# ...                     ...                 ...
# 76974                  1820                 944
# 77198                   483                 596
# 77250                   159                 352
# 77254                  4493                1997
# 77269                  1822                2012
#
#                                               status_url  \
# 29     http://twitter.com/einfachbloggen/statuses/540...
# 64     http://twitter.com/gwittrapp/statuses/54077604...
# 108    http://twitter.com/acolliver615/statuses/54055...
# 127    http://twitter.com/WillemelliW/statuses/540488...
# 128    http://twitter.com/Chapuler38/statuses/5404829...
# ...                                                  ...
# 76974  http://twitter.com/whereisyvette/statuses/5324...
# 77198  http://twitter.com/arrayson/statuses/532460192...
# 77250  http://twitter.com/drfarres/statuses/532460171...
# 77254  http://twitter.com/cocoy/statuses/532460170513...
# 77269  http://twitter.com/Del_Alpha/statuses/53246016...
#
#                                             entities_str  \
# 29     {"hashtags":[{"text":"Orion","indices":[19,25]...
# 64     {"hashtags":[{"text":"cometlanding","indices":...
# 108    {"hashtags":[{"text":"CometLanding","indices":...
# 127    {"hashtags":[{"text":"OrionLaunch","indices":[...
# 128    {"hashtags":[{"text":"orion","indices":[41,47]...
# ...                                                  ...
# 76974  {"hashtags":[{"text":"CometLanding","indices":...
# 77198  {"hashtags":[{"text":"CometLanding","indices":...
# 77250  {"hashtags":[{"text":"CometLanding","indices":...
# 77254  {"hashtags":[{"text":"cometlanding","indices":...
# 77269  {"hashtags":[{"text":"Cometlanding","indices":...
#
#       specific_applications   applications
# 29       Twitter for iPhone        Twitter
# 64            Gwittr Writer  Gwittr Writer
# 108     Twitter for Android        Twitter
# 127      Twitter Web Client        Twitter
# 128      Twitter for iPhone        Twitter
# ...                     ...            ...
# 76974    Twitter for iPhone        Twitter
# 77198    Twitter for iPhone        Twitter
# 77250    Twitter for iPhone        Twitter
# 77254       Twitter for Mac        Twitter
# 77269    Twitter Web Client        Twitter
#
# [1724 rows x 18 columns]

# %%
def getAllRetweetReplies(total_replies_df):
    retweet_replies = total_replies_df[total_replies_df['text'].apply(
        lambda x: True if re.search('^RT @.*', x) else False)]
    return retweet_replies

def getAllTweetReplies(total_replies_df):
    tweet_replies = total_replies_df[total_replies_df['text'].apply(
        lambda x: False if re.search('^RT @.*', x) else True)]
    return tweet_replies

retweet_replies = getAllRetweetReplies(total_replies_df)

tweet_replies = getAllTweetReplies(total_replies_df)

# %%
nan_reply_user_id_df = df[pd.isna(df['in_reply_to_user_id_str'])]
retweet_only_df = nan_reply_user_id_df[nan_reply_user_id_df['text'].apply(
    lambda x: True if re.search("^RT @.*", x)else False)]
tweet_only_df = nan_reply_user_id_df[nan_reply_user_id_df['text'].apply(
    lambda x: False if re.search("^RT @.*", x)else True)]

# %%
retweet_only_df
# Out:
#                    id_str        from_user  \
# 0      540930409279008768  amika0078788556
# 2      540929998388211713         MHuuskoL
# 3      540929346878599168  SaraGomezAranci
# 4      540929229052203008          CBCDay6
# 5      540928707947671555      MBernacconi
# ...                   ...              ...
# 77300  532460149668343808            m0cvo
# 77301  532460149215350784          ipanice
# 77303  532460148451581952           atieyK
# 77304  532460148254470144           j0nny5
# 77306  532460147764125696          grery92
#
#                                                     text  \
# 0      RT @VersaTechnology: Congratulations @Philae20...
# 2      RT @EUCouncil: After the #CometLanding - Astro...
# 3      RT @EUCouncil: After the #CometLanding - Astro...
# 4      RT @shaunmajumder: Feels good to be the @CBCDa...
# 5      RT @EUCouncil: After the #CometLanding - Astro...
# ...                                                  ...
# 77300  RT @ConversationUK: BREAKING: Philae lander ha...
# 77301  RT @esa: '@Philae2014 is gone - it's on its pa...
# 77303  RT @ObservingSpace: Weâ€™ve been waiting 10 ye...
# 77304  RT @maxplanckpress: Accomazzo (flight director...
# 77306  RT @dsdanyds: TopTrendIT: TT ITALIA 09:59\r\n1...
#
#                      created_at geo_coordinates user_lang  \
# 0     2014-12-05 18:07:14+00:00             NaN        en
# 2     2014-12-05 18:05:36+00:00             NaN        en
# 3     2014-12-05 18:03:00+00:00             NaN        fr
# 4     2014-12-05 18:02:32+00:00             NaN        en
# 5     2014-12-05 18:00:28+00:00             NaN        en
# ...                         ...             ...       ...
# 77300 2014-11-12 09:09:26+00:00             NaN        en
# 77301 2014-11-12 09:09:26+00:00             NaN        en
# 77303 2014-11-12 09:09:26+00:00             NaN        en
# 77304 2014-11-12 09:09:26+00:00             NaN        en
# 77306 2014-11-12 09:09:26+00:00             NaN        it
#
#       in_reply_to_user_id_str in_reply_to_screen_name from_user_id_str  \
# 0                         NaN                     NaN       1297570116
# 2                         NaN                     NaN        574434762
# 3                         NaN                     NaN       1057356487
# 4                         NaN                     NaN        177276897
# 5                         NaN                     NaN         47907492
# ...                       ...                     ...              ...
# 77300                     NaN                     NaN        103211582
# 77301                     NaN                     NaN         39744088
# 77303                     NaN                     NaN         58303715
# 77304                     NaN                     NaN         17914863
# 77306                     NaN                     NaN        487827577
#
#       in_reply_to_status_id_str  \
# 0                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5                           NaN
# ...                         ...
# 77300                       NaN
# 77301                       NaN
# 77303                       NaN
# 77304                       NaN
# 77306                       NaN
#
#                                                   source  \
# 0      <a href="http://twitter.com" rel="nofollow">Tw...
# 2      <a href="http://twitter.com/#!/download/ipad" ...
# 3      <a href="http://twitter.com/download/iphone" r...
# 4      <a href="http://twitter.com/download/android" ...
# 5      <a href="http://twitter.com" rel="nofollow">Tw...
# ...                                                  ...
# 77300  <a href="https://twitter.com/download/android"...
# 77301  <a href="http://itunes.apple.com/us/app/twitte...
# 77303  <a href="https://twitter.com/download/android"...
# 77304  <a href="http://twitter.com" rel="nofollow">Tw...
# 77306  <a href="http://twitter.com/download/android" ...
#
#                                        profile_image_url  \
# 0      http://pbs.twimg.com/profile_images/3555068293...
# 2      http://pbs.twimg.com/profile_images/4973510588...
# 3      http://pbs.twimg.com/profile_images/5391705804...
# 4      http://pbs.twimg.com/profile_images/4590694303...
# 5      http://pbs.twimg.com/profile_images/5331943059...
# ...                                                  ...
# 77300  http://pbs.twimg.com/profile_images/5001938819...
# 77301  http://pbs.twimg.com/profile_images/1667935129...
# 77303  http://pbs.twimg.com/profile_images/5057311637...
# 77304  http://pbs.twimg.com/profile_images/89991673/j...
# 77306  http://pbs.twimg.com/profile_images/3788000004...
#
#        user_followers_count  user_friends_count  \
# 0                       425                 113
# 2                       215                 310
# 3                       741                 310
# 4                      4331                2098
# 5                       317                 478
# ...                     ...                 ...
# 77300                  1430                 845
# 77301                   157                 350
# 77303                   354                1088
# 77304                    92                  63
# 77306                   194                 403
#
#                                               status_url  \
# 0      http://twitter.com/amika0078788556/statuses/54...
# 2      http://twitter.com/MHuuskoL/statuses/540929998...
# 3      http://twitter.com/SaraGomezAranci/statuses/54...
# 4      http://twitter.com/CBCDay6/statuses/5409292290...
# 5      http://twitter.com/MBernacconi/statuses/540928...
# ...                                                  ...
# 77300  http://twitter.com/m0cvo/statuses/532460149668...
# 77301  http://twitter.com/ipanice/statuses/5324601492...
# 77303  http://twitter.com/atieyK/statuses/53246014845...
# 77304  http://twitter.com/j0nny5/statuses/53246014825...
# 77306  http://twitter.com/grery92/statuses/5324601477...
#
#                                             entities_str  \
# 0      {"hashtags":[{"text":"Philae","indices":[49,56...
# 2      {"hashtags":[{"text":"CometLanding","indices":...
# 3      {"hashtags":[{"text":"CometLanding","indices":...
# 4      {"hashtags":[{"text":"MiniMansbridge","indices...
# 5      {"hashtags":[{"text":"CometLanding","indices":...
# ...                                                  ...
# 77300  {"hashtags":[{"text":"CometLanding","indices":...
# 77301  {"hashtags":[{"text":"CometLanding","indices":...
# 77303  {"hashtags":[{"text":"cometlanding","indices":...
# 77304  {"hashtags":[{"text":"CometLanding","indices":...
# 77306  {"hashtags":[{"text":"GUERRIERO","indices":[44...
#
#              specific_applications applications
# 0               Twitter Web Client      Twitter
# 2                 Twitter for iPad      Twitter
# 3               Twitter for iPhone      Twitter
# 4              Twitter for Android      Twitter
# 5               Twitter Web Client      Twitter
# ...                            ...          ...
# 77300  Twitter for Android Tablets      Twitter
# 77301              Twitter for Mac      Twitter
# 77303  Twitter for Android Tablets      Twitter
# 77304           Twitter Web Client      Twitter
# 77306          Twitter for Android      Twitter
#
# [59929 rows x 18 columns]

# %%
tweet_only_df
# Out:
#                    id_str       from_user  \
# 1      540930042700656640  ChrisDMarshall
# 6      540928513906589696       LukeGolds
# 9      540925590111789056   shaunmajumder
# 10     540925056533413888       EUCouncil
# 11     540924908797448193       LukeGolds
# ...                   ...             ...
# 77287  532460156567580672       JoeGrish1
# 77290  532460155859120128      charliecbs
# 77297  532460154482999296  worldbreakingn
# 77302  532460149084930049    ABForScience
# 77305  532460148238090240         nsentse
#
#                                                     text  \
# 1      CometWatch 2 December Â» Rosetta - ESA's comet...
# 6      USA Â» NEWS Â»  HOT NEWS 828 comet landing Phi...
# 9      Feels good to be the @CBCDay6 champion beating...
# 10     After the #CometLanding - Astronaut @astro_luc...
# 11     USA Â» NEWS Â»  HOT NEWS 534 comet landing The...
# ...                                                  ...
# 77287  And go! Philae separates from Rosetta, but sig...
# 77290  It will take seven hours for the #probe to fal...
# 77297  And go! Philae separates from Rosetta, but sig...
# 77302  This means  that the actual landing will be ar...
# 77305                   7 hours of waiting #CometLanding
#
#                      created_at geo_coordinates user_lang  \
# 1     2014-12-05 18:05:46+00:00             NaN        en
# 6     2014-12-05 17:59:42+00:00             NaN        en
# 9     2014-12-05 17:48:05+00:00             NaN        en
# 10    2014-12-05 17:45:58+00:00             NaN        en
# 11    2014-12-05 17:45:22+00:00             NaN        en
# ...                         ...             ...       ...
# 77287 2014-11-12 09:09:28+00:00             NaN        pl
# 77290 2014-11-12 09:09:28+00:00             NaN        en
# 77297 2014-11-12 09:09:28+00:00             NaN        pl
# 77302 2014-11-12 09:09:26+00:00             NaN        en
# 77305 2014-11-12 09:09:26+00:00             NaN        en
#
#       in_reply_to_user_id_str in_reply_to_screen_name from_user_id_str  \
# 1                         NaN                     NaN         42201214
# 6                         NaN                     NaN        619629656
# 9                         NaN                     NaN         17680518
# 10                        NaN                     NaN        206717989
# 11                        NaN                     NaN        619629656
# ...                       ...                     ...              ...
# 77287                     NaN                     NaN       2387053214
# 77290                     NaN                     NaN        169495645
# 77297                     NaN                     NaN       2309819160
# 77302                     NaN                     NaN       2333122519
# 77305                     NaN                     NaN         20434005
#
#       in_reply_to_status_id_str  \
# 1                           NaN
# 6                           NaN
# 9                           NaN
# 10                          NaN
# 11                          NaN
# ...                         ...
# 77287                       NaN
# 77290                       NaN
# 77297                       NaN
# 77302                       NaN
# 77305                       NaN
#
#                                                   source  \
# 1      <a href="https://dev.twitter.com/docs/tfw" rel...
# 6      <a href="http://ifttt.com" rel="nofollow">IFTT...
# 9      <a href="http://twitter.com/download/iphone" r...
# 10     <a href="http://twitter.com" rel="nofollow">Tw...
# 11     <a href="http://ifttt.com" rel="nofollow">IFTT...
# ...                                                  ...
# 77287  <a href="http://twitterfeed.com" rel="nofollow...
# 77290  <a href="http://twitter.com/download/iphone" r...
# 77297  <a href="http://twitterfeed.com" rel="nofollow...
# 77302  <a href="http://www.tweetcaster.com" rel="nofo...
# 77305  <a href="http://twitter.com/download/iphone" r...
#
#                                        profile_image_url  \
# 1      http://pbs.twimg.com/profile_images/228087980/...
# 6      http://pbs.twimg.com/profile_images/2344739619...
# 9      http://pbs.twimg.com/profile_images/1312790905...
# 10     http://pbs.twimg.com/profile_images/4838611162...
# 11     http://pbs.twimg.com/profile_images/2344739619...
# ...                                                  ...
# 77287  http://pbs.twimg.com/profile_images/4441120804...
# 77290  http://pbs.twimg.com/profile_images/3788000006...
# 77297  http://pbs.twimg.com/profile_images/4270311610...
# 77302  http://pbs.twimg.com/profile_images/4320695593...
# 77305  http://pbs.twimg.com/profile_images/3693655850...
#
#        user_followers_count  user_friends_count  \
# 1                       347                1286
# 6                       350                <NA>
# 9                     67013                1973
# 10                    52050                 360
# 11                      350                <NA>
# ...                     ...                 ...
# 77287                   173                  38
# 77290                  2163                  66
# 77297                   532                 472
# 77302                   155                 212
# 77305                   200                 267
#
#                                               status_url  \
# 1      http://twitter.com/ChrisDMarshall/statuses/540...
# 6      http://twitter.com/LukeGolds/statuses/54092851...
# 9      http://twitter.com/shaunmajumder/statuses/5409...
# 10     http://twitter.com/EUCouncil/statuses/54092505...
# 11     http://twitter.com/LukeGolds/statuses/54092490...
# ...                                                  ...
# 77287  http://twitter.com/JoeGrish1/statuses/53246015...
# 77290  http://twitter.com/charliecbs/statuses/5324601...
# 77297  http://twitter.com/worldbreakingn/statuses/532...
# 77302  http://twitter.com/ABForScience/statuses/53246...
# 77305  http://twitter.com/nsentse/statuses/5324601482...
#
#                                             entities_str  \
# 1      {"hashtags":[{"text":"CometLanding","indices":...
# 6      {"hashtags":[{"text":"cometlanding","indices":...
# 9      {"hashtags":[{"text":"MiniMansbridge","indices...
# 10     {"hashtags":[{"text":"CometLanding","indices":...
# 11     {"hashtags":[{"text":"cometlanding","indices":...
# ...                                                  ...
# 77287  {"hashtags":[{"text":"CometLanding","indices":...
# 77290  {"hashtags":[{"text":"probe","indices":[33,39]...
# 77297  {"hashtags":[{"text":"CometLanding","indices":...
# 77302  {"hashtags":[{"text":"CometLanding","indices":...
# 77305  {"hashtags":[{"text":"CometLanding","indices":...
#
#          specific_applications             applications
# 1         Twitter for Websites                  Twitter
# 6                        IFTTT                    IFTTT
# 9           Twitter for iPhone                  Twitter
# 10          Twitter Web Client                  Twitter
# 11                       IFTTT                    IFTTT
# ...                        ...                      ...
# 77287              twitterfeed              twitterfeed
# 77290       Twitter for iPhone                  Twitter
# 77297              twitterfeed              twitterfeed
# 77302  TweetCaster for Android  TweetCaster for Android
# 77305       Twitter for iPhone                  Twitter
#
# [15654 rows x 18 columns]

# %%
len(retweet_replies.index)  # replies that contain retweets
# Out:
# 30

# %%
len(tweet_replies.index)  # replying other tweets
# Out:
# 1694

# %%
retweet_total = df[df['text'].apply(
    lambda x: True if re.search('^RT @.*', x) else False)]
tweet_total = df[df['text'].apply(
    lambda x: False if re.search('^RT @.*', x) else True)]

# %%
len(retweet_total.index)  # Total retweets
# Out:
# 59959

# %%
len(tweet_total.index)  # Total tweets
# Out:
# 17348

# %%
retweet_only = len(retweet_total.index) - len(retweet_replies.index)

# %%
tweet_only = len(tweet_total.index) - len(tweet_replies.index)

# %%
replies_only = len(total_replies.index)

# %%
len(retweet_only_df)
# Out:
# 59929

# %%
len(tweet_only_df)
# Out:
# 15654

# %%
replies_only
# Out:
# 1724

# %%
def getNoOfUniqueUsers(df):
    average_different_users_tweet = df.groupby(
    ["from_user_id_str"]).agg(["count"])["from_user"]
    #average_different_users_tweet.mean()
    average_different_users_tweet.sort_values(by="count", ascending=False)
    man = average_different_users_tweet["count"].tolist()
    return len(man)

# %%
uniqueUsers = getNoOfUniqueUsers(df)

# %%
average_retweets_by_a_user = len(retweet_only_df) / uniqueUsers 
average_tweets_by_a_user = len(tweet_only_df) / uniqueUsers
average_replies_by_a_user = len(total_replies_df) / uniqueUsers

# %%
print("Average retweets by a user: " + str(average_retweets_by_a_user))
print("Average tweets by a user: " + str(average_tweets_by_a_user)) #(excluding retweets and replies)
print("Average replies by a user: " + str(average_replies_by_a_user))
# Out:
# Average retweets by a user: 1.193424406563645
# Average tweets by a user: 0.3117333120917636
# Average replies by a user: 0.034331687111677556

# %%
def readCSV():
       df = pd.read_csv("../data/CometLandingFixed.csv",
                     dtype={"id_str": str, "in_reply_to_user_id_str": str, "from_user_id_str": str,
                            "in_reply_to_status_id_str": str, "user_followers_count": "Int64",
                            "user_friends_count": "Int64", "geo_coordinates": str}, parse_dates=['created_at']
                 )
       return df

# %%
class Tests(unittest.TestCase):
   # Test on if filtering of dates is functioning properly.
   def test_one(self):
      df = readCSV()
      start_date = time.mktime(datetime.datetime.strptime('2014/11/12', "%Y/%m/%d").timetuple())
      end_date = time.mktime(datetime.datetime.strptime('2014/12/06', "%Y/%m/%d").timetuple())

      test_date_after_out = time.mktime(datetime.datetime.strptime('2014/12/07', "%Y/%m/%d").timetuple())
      test_date_before_out= time.mktime(datetime.datetime.strptime('2014/11/11', "%Y/%m/%d").timetuple())

      dfTest = fd.filterOutDates(df)
      for date in dfTest['created_at']:
          self.assertEqual(True, (date.timestamp() >= start_date))
          self.assertEqual(True, (date.timestamp() < end_date))

      self.assertEqual(False, (test_date_before_out >= start_date))
      self.assertEqual(True, (test_date_before_out < end_date))

      self.assertEqual(True, (test_date_after_out >= start_date))
      self.assertEqual(False, (test_date_after_out < end_date))

   pass
      
   # Test on if filtering of duplicates and null records is functioning properly.
   def test_two(self):
      df = readCSV()
      noOfRecordsBefore = len(df)
      
      dfTest = fd.removeDuplicatesNullRecords(df)
      noOfRecordsAfter = len(dfTest)
      self.assertEqual(noOfRecordsBefore, noOfRecordsAfter) # Nothing removed

      df.iloc[noOfRecordsBefore - 1] = df.iloc[1]
      #df.iloc[noOfRecordsBefore - 2] = NULL
      noOfRecordsBefore = len(df)
      dfTest = fd.removeDuplicatesNullRecords(df)
      noOfRecordsAfter = len(dfTest)

      self.assertEqual(noOfRecordsBefore - 1, noOfRecordsAfter) # One duplicate record removed

   pass

   # Test on if only replies can be found.
   def test_three(self):
      df = readCSV()
      replies = getAllReplies(df)

      # Checks they are all replies.
      for i in replies['in_reply_to_user_id_str']:
         self.assertEqual(True, pd.notna(i))

      tweets = getAllTweets(df)
      df.iloc[len(df) - 1] = tweets.iloc[1]

      # Checks that new tweet for example is not accepted.
      self.assertEqual(False, pd.notna(df['in_reply_to_user_id_str'][len(df) - 1]))
   pass

   # Test on if all retweets can be found.
   def test_four(self):
      df = readCSV()
      retweets = getAllRetweets(df)

      # Checks they are all retweets.
      for i in retweets['text']:
         self.assertEqual(True, i.startswith("RT @"))

      tweets = getAllTweets(df)
      df.iloc[len(df) - 1] = tweets.iloc[1]

      # Checks that new tweet for example is not accepted.
      self.assertEqual(False, df['text'][len(df) - 1].startswith("RT @"))
   pass

   # Test on if all tweets can be found.
   def test_five(self):
      df = readCSV()
      tweets = getAllTweets(df)
      for i in tweets['text']:
         self.assertEqual(False, i.startswith("RT @"))

      retweets = getAllRetweets(df)
      df.iloc[len(df) - 1] = retweets.iloc[1]

      # Checks that new tweet for example is not accepted.
      self.assertEqual(True, df['text'][len(df) - 1].startswith("RT @"))
   pass

   # Test on if only retweet replies can be found.
   def test_six(self):
      df = readCSV()
      retweet_replies = getAllRetweetReplies(getAllReplies(df))
      for i in retweet_replies['in_reply_to_user_id_str']:
         self.assertEqual(True, pd.notna(i))
      for i in retweet_replies['text']:
         self.assertEqual(True, i.startswith("RT @"))

      tweets = getAllTweets(df)
      df.iloc[len(df) - 1] = tweets.iloc[1]

      # Checks that new tweet for example is not accepted.
      self.assertEqual(False, df['text'][len(df) - 1].startswith("RT @"))
      self.assertEqual(False, pd.notna(df['in_reply_to_user_id_str'][len(df) - 1]))
   pass

   # Test on if only tweet replies can be found.
   def test_seven(self):
      df = readCSV()
      tweet_replies = getAllTweetReplies(getAllReplies(df))
      for i in tweet_replies['in_reply_to_user_id_str']:
         self.assertEqual(True, pd.notna(i))
      for i in tweet_replies['text']:
         self.assertEqual(False, i.startswith("RT @"))

      retweets = getAllRetweets(df)
      df.iloc[len(df) - 1] = retweets.iloc[1]

      # Checks that new retweet for example is not accepted.
      self.assertEqual(True, df['text'][len(df) - 1].startswith("RT @"))
      self.assertEqual(False, pd.notna(df['in_reply_to_user_id_str'][len(df) - 1]))
   pass

   # Tests that all replies are kept when they are split.
   def test_eight(self):
      df = readCSV()
      replies = getAllReplies(df)
      tweet_replies = getAllTweetReplies(replies)
      retweet_replies = getAllRetweetReplies(replies)
      self.assertEqual(len(replies), len(tweet_replies) + len(retweet_replies))
   pass

   # Tests that unique users amount is found.
   def test_nine(self):
      df = readCSV()
      df.iloc[1] = df.iloc[5]
      df.iloc[2] = df.iloc[5]
      df.iloc[3] = df.iloc[5]
      df.iloc[4] = df.iloc[5]
      uniqueUsers = getNoOfUniqueUsers(df)
      uniqueUsersTest = len(df["from_user_id_str"].unique())
      self.assertEqual(uniqueUsers, uniqueUsersTest)
   pass

   # Tests that unique hashtags are found.
   def test_ten(self):
      df = readCSV()
      allHashtags = getListOfAllHashTags()
      unique = getListOfUniqueHashtags(allHashtags.append('67P'))
      newunique = pd.Series(allHashtags)
      unique2 = newunique.unique()

      self.assertEqual(len(unique) < len(allHashtags), True)
      for i in range(len(unique)):
         self.assertEqual(unique[i], unique2[i])
      
   # Tests that top 25 hashtags are the same found in functions.
   def test_eleven(self):
      df = readCSV()
      allHashtags = getListOfAllHashTags()
      unique = getListOfUniqueHashtags(allHashtags)
      newdf = createDataFrameOfHashtagsAndFills(unique, allHashtags)
      newdf2 = newdf.reset_index()
      for i in range(25):
         self.assertEqual(newdf2['Frequency'][i], allHashtags.count(newdf2['Hashtags'][i]))
   pass

# %%
def suite():
 loader = unittest.TestLoader()
 testsuite = loader.loadTestsFromTestCase(Tests)
 return testsuite

# %%
def test():
 testsuite = suite()
 runner = unittest.TextTestRunner(sys.stdout, verbosity=2)
 result = runner.run(testsuite)

# %%
test()
# Out:
# test_eight (__main__.Tests) ... ok
# test_eleven (__main__.Tests) ...
# C:\Users\thoma\AppData\Local\Temp/ipykernel_9220/3105913847.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Frequency'][index] += 1
# ok
# test_five (__main__.Tests) ... ok
# test_four (__main__.Tests) ... ok
# test_nine (__main__.Tests) ... ok
# test_one (__main__.Tests) ... ERROR
# test_seven (__main__.Tests) ... ok
# test_six (__main__.Tests) ... ok
# test_ten (__main__.Tests) ... ok
# test_three (__main__.Tests) ...
# C:\Users\thoma\AppData\Local\Temp/ipykernel_9220/3105913847.py:21: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   hashtagsUnique = pd.Series(hashtagsFull)
# ok
# test_two (__main__.Tests) ... ok
#
# ----------------------------------------------------------------------
# Ran 11 tests in 71.726s
#
# FAILED (errors=4)

# %%
# https://stackoverflow.com/questions/16476924/how-to-iterate-over-rows-in-a-dataframe-in-pandas
#Network X

replies_network = nx.Graph()
seenNodes_replies = set()

for index, row in total_replies_df.iterrows():
    node_1 = row['in_reply_to_screen_name']
    if node_1 not in seenNodes_replies and node_1 is not None:
        replies_network.add_node(node_1)
        seenNodes_replies.add(node_1)
        
    node_2 = row['from_user']
    if node_2 not in seenNodes_replies and node_2 is not None :
        replies_network.add_node(node_2)
        seenNodes_replies.add(node_2)
        
    replies_network.add_edge(node_1,node_2)
  
    
    print(row['in_reply_to_screen_name'], row['from_user'])
# Out:
# NASA einfachbloggen
# nathanbroon gwittrapp
# ESA_Rosetta acolliver615
# ESA_Rosetta WillemelliW
# RT_com Chapuler38
# NASA_Orion TonyPethtel
# ReginePetersen mazmanian
# ScienceNews IsidoraBojovicc
# treyhughett1 cunningham_dc
# Philae_Ptolemy masanorimusic
# rtistforhire rtistforhire
# ESA_Rosetta mixelaneo
# carolynporco LaTambourine
# teobesta teobesta
# ESA_Rosetta masanorimusic
# GummyTraveler GummyTraveler
# ESA_Rosetta einfachbloggen
# Discovery Nijin_Koshy
# lcfleming leppx
# universetoday kpcuk
# me_too Melissandre_L
# esa EvidenceBDave
# JohnRMoffitt s0cialblast
# ESA_Rosetta einfachbloggen
# ESA_Rosetta kichyedesh
# FarSight3 astro_geo
# AmyAmylou1993 AmyAmylou1993
# CoryBooker the_amphibian
# fezIet AmyAmylou1993
# nm_edm nm_edm
# EuropeanSpace LordBexar
# esaoperations ElaineHansen888
# nitrogen_15 MonicaGrady
# RogerHighfield davidshukmanbbc
# JFKLibrary Uzu_Brady_3000
# royalmailnews mrsdenyer
# SeekTwit VanessaJades1
# Philae2014 KarewiKaulissch
# DLR_en einfachbloggen
# esa Sannsibble
# ESA_Rosetta BorisSbarufatti
# ESA_Rosetta ononerail
# ESA_Rosetta Jillian_Scudder
# ESA_Rosetta esa
# Philae2014 Arch2330
# mariekebaan NATURALIS_AD
# EuroGeosciences Besserwisser45
# Mggtaylor akanel
# ejival eaviles
# BBCEngland TomwyerTom
# fcain NewThor
# Philae_Ptolemy RosettaInTheUK
# Grenoble_Isere SharonRehbinder
# BBCPallab Murkfury
# mashable miarmc
# Philae2014 Mercury3488
# LabourEoin permakill
# matthiascarter matthiascarter
# Audi now14amy
# Philae2014 ShamimRahman
# IngAlfieri SerieA100
# Garrettishere Garrettishere
# Astro_Flow AishaG10
# Philae2014 zoldycks
# irishexaminer cpd_spd
# antonio13maria5 gabriela_ross84
# akanel icarusfactor
# mrpeshields chairofrust
# katiana_migue47 noel_mariaosu99
# neverjessie larkened
# Philae2014 akunamatataaaa
# PoliticsNation AishaG10
# ESA_Rosetta peetaurus
# Garrettishere Garrettishere
# zeniuseducation RFDAJ
# Philae2014 OpenIQE
# BadAstronomer Cosmic_Calendar
# WSJ cold__rush
# StarTalkRadio RuyPlatt
# edshow AishaG10
# BBCBreaking PossibilityTV
# Philae_ROMAP Philae_ROMAP
# alami89 _bourar
# JonathanRaven JonathanRaven
# CoolAstronomer rachaelcohen
# Philae2014 LilyH2O
# BBCBreaking glenn_rig_out
# sandentotten GeoffreyGiller
# Philae2014 differentspain
# edshow lunaticial
# ObservingSpace Tozzo1991
# ItsTheDoctor tlee329a
# nytimesscience ShitMyFoodMakes
# Philae2014 dantsis87
# sandwarbler sandwarbler
# edshow AishaG10
# ausgeo HelloSandraLove
# undeux celamowari
# GoodyDwr DrJagz
# Philae2014 peetaurus
# Philae2014 ozge_ersoy
# ABCNews24 nicolasnicola22
# edshow francie57
# ladykanzki ladykanzki
# BW shinescouts
# edshow AishaG10
# ESA_Rosetta attack_of_mars
# NASA Austra78
# DrPhiltill paulamunn
# tagesspiegel carstensass
# FChiusaroli SusanaRecio_
# DiegoU Voyager_M
# Andante_C_C Northumbrianman
# PBS marieeballard
# nycjim GabrielleNYC
# mudandcowbells andtheunicorn
# Discovery_Space ikluft
# Philae2014 The_Casks
# chrislintott ChristieKas
# effymazz MazzyD3
# nprscience peterdedmonds
# mggtTaylor johnlbw
# edyong209 Katherineqi
# Philae2014 MagiKey
# krolek robertvg
# Philae2014 KalPatel
# benjiperson squizataxidermy
# ArmaghPlanet Cleverestcookie
# FChiusaroli terminologia
# Philae2014 amanchor
# Philae2014 ivankailic
# Philae2014 RonCrean
# ESA_Rosetta RBCHeatherClark
# esa Mdldp
# ESA_Rosetta DimitriKanis
# Philae2014 jeffreybrown57
# WestBriton ParmesanMark
# ESA_Rosetta ozzez
# mavcunha snap_ci
# Philae2014 Robinhood_68
# BBCBreaking paul_a_smith
# appleaddicto AndrewHavis
# seemstoonytunes sammy_soso
# PeterLeyssens megsalamode
# Team_Maths ullviu
# AdeCapon StaceyGreen_SH
# ESA_Rosetta dotero555
# esaoperations TomasMolinaB
# gracepoint555 gracepoint555
# ericarolfe timmermansr
# edshow AishaG10
# Philae2014 DEXTHEMUSICMAN
# viniciusroseira viniciusroseira
# eroston akuchment
# CNN RichieVaughan88
# Philae2014 scandavader
# ESA_Rosetta swm0904
# Philae2014 AerospacePoliMI
# ESA_Rosetta dan_bodkin
# catalagerard NilBellmunt
# Philae2014 bethanmp
# sbearbergman Harringtonkent
# Nshatner CptBuchi
# olafureliasson marioporpora
# generalelectric Mohamed_Adams
# Philae2014 requiemxl
# Stwallace23 JimmyBear2
# OpenMarsInfo sergeography
# ESA_Rosetta BraveBeing
# edshow LBC1961
# edshow littleredblog
# edshow Cwallace49
# Philae2014 TerhiSakara
# Philae2014 judywang
# ESA_Rosetta es4ideas
# ESA_Rosetta eugeped
# Philae2014 traceyb65
# Philae2014 Eng_IMF
# Philae2014 hatzbymm
# ASI_spazio Livmarnel
# matthiascarter matthiascarter
# Philae2014 NortonOnline
# elakdawalla Sungrazr
# elakdawalla elakdawalla
# Philae2014 PrintrbotLearn
# WoahThereJen dragoblade7
# HeckPhilly tapper
# ESA_Rosetta AcmeWorks
# WoahThereJen dragoblade7
# ESA_Rosetta AirlieWalsh
# jannekekampen QuirienVerbakel
# ESA_Rosetta McGonagallsMuse
# Philae2014 amadorredondo
# Philae2014 JoannaMDennis
# Warruz HekaCat
# Philae2014 aquasmashau
# Jonny6099 dragoblade7
# RobHuyser timmermansr
# elakdawalla twistator
# Philae2014 LankaFayasNews
# fraueickmann frsearch
# AntonioParis debilperson66
# WoahThereJen Jonny6099
# Oatmeal tanyaofmars
# astrostephenson WGSSCairnCrew
# deBeauxOs1 fernhilldammit
# BrookesTimes mr_skylord
# disinformatico blaineilmono
# NASAWatch Lisari23
# GregShum Katie_PhD
# ESA_Rosetta aerokura
# genejm29 ouimaisnon1
# Philae2014 drawnyourtweet
# mggtTaylor astrokellie
# ESA_Rosetta NuclearAnthro
# Philae2014 voromax
# JanHattenbach JanHattenbach
# BatchelorKim NetflixUK
# YasminAslam ScottSpezio
# skyatnightmag mrgplewis
# esa forwart_design
# KalenBergado Fishmaster_s
# doug_ellison AndiDolphin
# belindaparmar urbie
# wyxcream egilpons
# lanewood allaboutgeorge
# Philae2014 allaboutgeorge
# neiltyson allaboutgeorge
# esa skunkiii
# esa woodputter
# DemocraticZone SerieA100
# mcuban GnomeFighter3D
# ESA_Rosetta rein91den
# Philae2014 angel_ahc
# Marmel moiskd
# ESA_Rosetta csete
# ghager50 amber_muir
# esaoperations newslotus
# Philae2014 spanishiron
# Philae2014 teresacardenes
# hiemeyer hiemeyer
# matteorenzi bollicina63
# Warruz HekaCat
# ESA_Rosetta RemivanTrijp
# mars_stu bdocs
# ESA_Rosetta seantchapman
# MayraFloresDM GoCaltrain
# ThinkOutOfBoxe MysteryDigger
# Philae2014 SaveTheComet
# ESA_Rosetta mediame_jas
# ESA_Rosetta 0wastesolutions
# SteRoPo JeffreyGuterman
# JonMoonie RadioKate
# broadfordbrewer Bodie15
# ESA_Rosetta DavidAGaspar
# Philae2014 Robinhood_68
# Philae2014 JR_TM24
# ESA_Rosetta EsadMehmeti
# RollercoasterGB RollercoasterGB
# ESA_Rosetta Helen_Crane
# Philae2014 A_Koppenhoefer
# MrsHallidays4th tedthartley
# SimoneEnomys xvivodiobrien
# digizaal HekaCat
# paddypower UncleErniesTips
# Philae2014 redaniel_18
# riascience olgabychkova
# patterballs KJ_Lutz
# BBCBreaking mac_suga
# Philae2014 LondonFuture
# jeffmas1 anantfinity
# Philae2014 AchiBaramidze69
# ESA_Rosetta MomAtheist
# ItsTheDoctor RyanR189
# astro_luca SuperErmy
# Philae2014 Fruehwirthfragt
# Philae2014 MachaelWade
# esa_es maribelpva
# matteorenzi mubblemubble
# Philae2014 time_motion
# CBCAlerts hockey_daisuki
# Philae2014 ChriDeClercq
# esa_es maribelpva
# AstronomyNow AMaddy2
# carlykapln AriseVSInc
# ItsTheDoctor chicaaaaaaago2
# Philae2014 StuWragg
# DrOrtizCardona RobbyCortes
# Joshlander93 HekaCat
# ESA_Rosetta DeboraMapelli
# Philae2014 DrAndreDavid
# MarsCuriosity drol007
# DrOrtizCardona RobbyCortes
# NASA horizons1983
# OndaCero_es Bioeder_Tech
# MonicaGrady arosha
# Warruz HekaCat
# jonnythesconny GhostRunner23
# NASA CurroPasquau
# BBCBreaking SHEENtrainwreck
# Inno4Europe DuifNL
# Philae2014 bwesoky
# Philae2014 Diplomacy140
# Philae2014 Diplomacy140
# Philae2014 Diplomacy140
# Philae2014 Diplomacy140
# Philae2014 Diplomacy140
# Philae2014 Diplomacy140
# Philae2014 masanorimusic
# Philae2014 poissento
# Philae2014 Diplomacy140
# nytimesscience AgentSecretX27
# lionelferra markhardaker
# Philae2014 Diplomacy140
# mcnees Jezebel4u
# ESA_Rosetta frank_golden90
# _ReBrick FelixFutcliffe
# googleitalia techstationit
# Philae2014 la_informacion
# filmbuffbaker jrgigl
# DAVIDsTEA kylekemper
# BBCBreaking gertjanvdb
# Philae2014 saskboy
# ajam erica_pitzi
# GeertHub SteveLussier
# Gicharuthemayor Mumbi_
# MBUSA navapesca
# AstroKatie ERN_Malleyscrub
# esa ItsClaireParker
# NASA CanoeReader
# Sparkly77 darrinsunstrum
# NASA talpinus
# ESA_Rosetta The_SolarSystem
# esaoperations RantiveMike
# Philae2014 MiraUnDragon
# dallascampbell alasdairscott
# joetek shimpster
# Philae2014 Ostedivino
# google Elisafish
# Philae2014 juhapa
# lapaseata Amigodewilson
# Philae2014 DonQuijoteMUC
# ObservingSpace Jezebel4u
# NASA PiersFrench
# PJSActor bejaypea
# TarexOrthver vinctee
# TIME djcool62
# Philae2014 DALLASSGRIER
# ESA_BE ReneeTeughels
# esascience thekerola
# BBCBreaking KateFanning
# JackMerlin Di9it8
# joetek foreverfalcon
# StLouisLindsay kylekemper
# salvatorRosa 30hmcVicky
# BBCBreaking sarahkhitchon
# genetics_blog graphcommons
# hold50 gsmontag
# Philae2014 csantoshc
# kylebap ritaelise
# BBCBreaking MrScottRMiller
# Philae2014 MsTexas1967
# ShuttleCDRKelly seanrsimons
# esa argendino
# e2v GavinGJohnson
# SPACEdotcom MeMarie21
# Thestred Thestred
# DextorpAxterix torukmako
# BadAstronomer playingwithdust
# ESA_Rosetta Anduminas
# ESA_nl johanellen
# TraceyProudlock London74Grant
# BBCBreaking SuMaskell
# CNES Bilsens
# KosmosZoid KosmosZoid
# Philae2014 dogcanyon
# HanFreakinSolo robertasaliani
# MichelleDBeadle scratchex
# BBCBreaking politik_riikr
# esascience magm61
# BBCBreaking IPACA_Library
# ESA_Rosetta marybethpearse
# BBCBreaking char_spurdens
# esa danielkrall22
# AwesomeAstroPod ActiveAstro
# Neil16B theanniemartin
# Philae2014 kalpeshmorarji
# chrislintott oenanthe54
# Ardbeg_de 1337MATE
# BBCBreaking goat211
# Philae2014 Nayaonce
# BBCBreaking CarrieDavy
# Philae2014 vinylbaustein
# esaoperations Swedebit
# micgramaglia garfishgarth
# Llawen Llawen
# Philae2014 _sarisabel_
# dcas1978 mikeyinaminute
# BBCBreaking danlozanov
# CNES ESA_fr
# Philae2014 DebTesh
# JPMajor Siralanhe
# esa KajaGlomb
# ESA_Rosetta SLIL1
# FLOWsnowboardn StudieuBelGeul
# Philae2014 PlanetarioLP
# ESA_Italia agaddone
# ESA_Rosetta christo1310
# Neil16B xucabob
# esascience Selmasi
# Marliesvdwalle Mickiflodi
# ESA_Rosetta DanielFMerritt
# esa TripleTheFocus
# esequieltiend54 emanuel23javiil
# BBCBreaking ArianaYakas
# MikeOkuda isolinearchick
# spacegovuk Roger_J_Clark
# mashable about_scout
# JPMajor Its_sheddiyounG
# Peter_Woodcock_ LaurieB_23
# TheOrangeCone michaeldewell
# Philae2014 UnNomdePlume
# PopMech AnnemarieChapde
# Philae2014 miamiempeditor
# Philae2014 masanorimusic
# mashable emily_aasand
# BecRyan meganlouu93
# loisi_enza DonatoSCARPA
# abbeylinegold ColetteLohr
# tomrichards07 edwiebe
# esaoperations ObiShawnC
# dcas1978 TimVickerstaff
# Philae2014 nilsmind
# SpaceflightNow StefSimanowitz
# esa ChloeCoombs5
# Philae2014 gwinniejones
# Philae2014 beppuvobern
# serpientes72 KmunityOfEquals
# AFP KCTVPhotogBrett
# ESA_Rosetta gregkallinson
# Philae2014 pete_cia
# Neil16B moragkatie
# pwbrewer mikbre
# starwars Jaden1138
# Philae2014 tanta1ise
# Philae2014 IFOLLOWBACK_66k
# NASA annoyed_patriot
# Philae2014 evasnijders
# SonyElectronics Its_sheddiyounG
# esaoperations elinevb
# CarlosTP_HU jgfalaguera
# KosmosZoid KosmosZoid
# pandemia angloventriglia
# Volatar AT1ST
# Philae2014 waltopaska
# 1Asemanii antihistamin
# EuropeanSpace chandpers
# Philae2014 JaedenStormes
# twcMariaLaRosa Scottr3126
# Philae2014 EurekaCafeSF
# Boeing tahoecwl
# lindsay40k guingb
# serpientes72 Tom_Coulthard
# Philae2014 sergenozmercan
# ESA_Rosetta MarcGozlan
# ESA_Rosetta MeMarie21
# BBCBreaking AaryanOberoiRox
# supervisorist supervisorist
# Erebuss lpenou
# Philae2014 RomainGuefveneu
# planetlabs hadfieldreckons
# OfficialTewot Its_sheddiyounG
# mirikramer StephenClark1
# ABC JeffreyOKeller
# BBCBreaking beccy_dixon
# ESA_Rosetta dr_s_williams
# rosenmusiccorp NASA
# Philae2014 marjar147
# Philae2014 2011guptashalin
# Philae2014 nme94
# Philae2014 guptasha2006
# Philae2014 nsentse
# DougBenson TheBioscopist
# Philae2014 stimpy
# Philae2014 Darka2000
# Philae2014 antzpantz
# Philae2014 benjgorman
# Philae2014 AlexScott381
# ESA_Rosetta ClarkeConsult
# Philae2014 alex_scr1pt
# alaricalbarda alaricalbarda
# esaoperations FVendely2112
# BostonGlobe Clare2e
# nrcook15 ArchitectureO
# BBCBreaking BBCBreaking
# Philae2014 SpaceOddity
# OSIRISREx PWGS
# matzd ThomasD83
# Mars_Amr attractive1977
# Philae2014 rem_albert
# terminologia teenwolf4798
# roy_d dexbob
# Philae2014 SeanWilliams137
# Summer_Ash AThingsfrench
# TannieEvita neddylees
# ESA_Rosetta MarcTremblay
# SpaceflightNow ifriendlyharry
# jbprime hubii
# hilalsumengen 3Tomloki
# giggs_boson bazblackadder
# BenBrownBBC jd_leveller
# Philae2014 AriWeather
# lplcarrette ejrquartz
# AFCWimblyWombly ShoutyMouse
# docpickles docpickles
# RachidRouis BaylorLong
# Philae2014 powellstacie
# Philae2014 FDinfu
# JohnRMoffitt JanetPhD
# ESA_Rosetta x3phillips
# NASASocial bluesmanSINY
# Philae2014 BHudders
# bananabergf1 azechka
# JanHattenbach _HADES1
# andreasmenn peterj_ej
# Philae2014 mc_mietz
# EFEciencia InfoMeteoTuit
# ESA_Rosetta stjornufraedi
# ESA_Rosetta LeahChes
# neiltyson JoeyRobots
# teshelen nationaltrust
# ESA_Rosetta YourMKWeb
# csa_asc mrcitythinks
# BBCStargazing SimonZerafa
# muellerspace NerdyAmy
# Philae2014 AlienGabe
# NASASolarSystem markcojuangco
# 1ChrisKnapp thelightinlife
# Philae2014 _RoseCitron_
# neiltyson CqJensen
# DutchManPaul RobertNickson
# Shiv_L troublein421
# Philae2014 j3blalock
# Philae2014 jaespinmora
# ESA_Rosetta perdalum
# ESA_Rosetta tom80807
# Juliaenlaonda RojoCabreado
# AstroyFisica fjsevilla
# ESA_Rosetta silviastruthers
# ESA_Rosetta freyplays
# isa_MYB theGasan
# ESA_Rosetta andrespaolino
# ESA_Rosetta kprxtl
# BBC_WHYS karki_aakriti
# DLR_next unterweltwunder
# Philae2014 iambinaxx
# MaxSalsbury24 SashaDeepwell
# ESA_Rosetta Mirky_MB
# ESA_Rosetta PareshMhetre
# esaoperations NovaNina
# futuretrek futuretrek
# Philae2014 Melissa2t
# ESA_Rosetta toktokalweer1ei
# RosettaInTheUK MonicaGrady
# mandaYoho mcnees
# ESA_Rosetta Yootha
# ESA_Rosetta sUASnews
# josuebecerra Big_M
# CISNCountry ryeisenberg
# SkroZoC _Yond
# RadiactivoMan RojoCabreado
# RaeannRooms fleetstreetfox
# Philae2014 thelightinlife
# epenser Rational_P
# ESA_Rosetta Pablote1603
# RosettaInTheUK MonicaGrady
# NASA EdBezooijen
# nationaltrust emisgoodeating
# Philae2014 alexgiamby
# ESA_Rosetta thewickedSin
# GirlForScience SPBianchini
# JulieDiCaro PsyMar
# Oberhummer Lykaion
# Philae2014 True_Q
# esaoperations twcspacewx
# RyanNewYork Riverseeker
# mars_stu juanjogom
# ToriHerridge ToriHerridge
# esa elliottwynkoop
# ESA_Rosetta ScaryItalian
# ESA_Rosetta windsorAndy
# ESA_Rosetta NaturalMessiah
# DLR_next marcusD1906
# NASA DSM
# emisgoodeating nationaltrust
# Philae2014 deanorhodes
# ESA_Rosetta clcabo
# ESA_Rosetta NovaNina
# scottgu Findel
# mashable theSeanPower
# libbydoodle NerdyAmy
# sondy Poletro
# Philae2014 likedeeler3
# generalelectric civicindia
# lephryk Commander1024
# NzRv HappyJiggly
# ESA_Rosetta EdBezooijen
# danigeos danigeos
# spacewriter rosiris1968
# ESA_Rosetta BLMagazine
# GirlForScience MurphyBits
# Philae2014 Philae_COSAC
# ESA_Rosetta unaimagen_
# AstroFranka EllaMason
# Philae2014 ColleenWhelpley
# Philae2014 SpaceHedge
# rockytopinsider NorrisGoose
# RPES12 _mygadgetlife
# Philae2014 sweesoccer
# BDCH joannekarma
# Philae2014 rap_fernandez
# Philae2014 rap_fernandez
# NASA kpmcgloshen
# teobesta teobesta
# NASA tristamsparks
# ARTEfuture Labeur33
# esa BeckinghamPeter
# mars_stu nivnac
# Philae2014 parkerpublicist
# taniaj78 SotonAstrodome
# NASA MarcoAEMH
# DeneanCaperton DeneanCaperton
# DLR_de MediaCologne
# NASA erdgerecords
# Philae2014 SchoolerLA
# PaolaHolguin TwitCesar
# DigitalPhotoTrk Lester_Tiger
# LucyAbigail_ sebastiantempl
# astrolapalma astro_turismo
# swissnexSF JuliaClaud
# aberron n3ke
# teobesta teobesta
# twitter Betelgeuse10
# Philae2014 AGHamilton
# RogerSMetcalfe charbhardy
# NASA TactileArchaeol
# benncass VideoScribeApp
# NASA MatteoBertBerti
# argentinomota tarsisazevedo
# MarkRoberts_1 MarkRoberts_1
# Philae2014 Jadlarry
# esascience PeoplesAstro
# Philae2014 WolfgangSchlte1
# VolkerRahn VolkerRahn
# Philae2014 SallyAAtkinson
# antpugh VideoScribeApp
# MrRichPalmer MrRichPalmer
# Keaton_S KeithMansfield
# ESA_Rosetta Kim_PPI
# theSparc_ AlexandraMassey
# Philae2014 DaKangaroo
# eevblog SpiderElectron
# Meteor_Mobile MyTutorWeb
# brobof AlexandraMassey
# VideoScribeApp buddyxo
# ESA_Rosetta whylime44
# britinfluence BecauseWeMust05
# AstronomyNow EgmondDennis
# teobesta teobesta
# Philae2014 philipobrien
# masanorimusic BBC_Tom
# LaVanguardia JulioMiravalls
# fleetstreetfox MrFarty
# Philae_MUPUS masanorimusic
# Philae2014 Kuchengnom
# NASA michael105uk
# gewoondennis42 MarcVisser90
# hastroparr Roy_Astro
# Harvela_ Harvela_
# xkcdComic bdamokos
# Philae2014 Kervie
# slowshooting slowshooting
# giornalettismo nadia_palladino
# Philae2014 DeltaIsForCain
# Orkeren1307 tristamsparks
# godoy42 marcelobeccari
# ESA_Rosetta indygadgetguy
# britishmuseum AcerSusan
# DanielInFlight MorkenTheMonk
# Philae2014 jamesclay
# Philae2014 dogcanyon
# CiteEspace ArthurRomeyer
# DLR_de fuks69
# ESA_Rosetta SimoHighbury
# nchazarra elefenor
# ajturner brobof
# newscientist KalbaKabuki
# di_rolf di_rolf
# IamHappyToast Scientificast
# esa HorusHelio
# ESA_Rosetta StarTranslation
# Philae2014 schlauschlau
# presentcorrect DuffyMedia
# ESA_Rosetta woroworld
# Researchagain Researchagain
# ESA_Rosetta scinet_it
# Magallonico SolentinameIsla
# Philae2014 eezzed
# dwfletch1 dwfletch1
# fleetstreetfox salvatorRosa
# METEOVISUAL Divulgameteo
# NASA wizadora1230
# marianlturner _NIKD_
# alisonatkin DirkNC
# macsnider DaFisch
# ObservingSpace cthreeo3
# SPACEFLIGHT101 AAW_Darmstadt
# alokjha jonmbutterworth
# DaFisch DaFisch
# ObservingSpace vimalk78
# mggtTaylor tristamsparks
# Philae2014 mr_3LiON
# andrewnelson Marilyn_Res
# TB_Times Gothic_Bucs_fan
# eefjie asjicvd
# twitter SPACEetc
# SchnabsiX PileOfSalt
# ESA_Rosetta GiuseppeTurrisi
# ObservingSpace ObservingSpace
# Scientificast isapinza
# telenoticias7 AquirosT
# esa GreenRATM
# Murk_Loar weather_wa
# ericarolfe DorotheaRead
# igallupd BeritEllingsen
# ESA_Rosetta gernot_t
# linc0lnpark Its_sheddiyounG
# NewHorizons2015 samooja
# DavidBrin GeorginaBencsik
# DawnSunrise1 HowJoeGod
# newburyastro DawnSunrise1
# MetroUK darrendunbar70
# suthers Philae_Ptolemy
# ESA_Rosetta lewbo89
# mariekebaan Its_sheddiyounG
# Avadit_Uptahir awessen
# 3sat nasanasal
# keaneofficial spacemanfellow
# Philae2014 JohnWrightUK
# margabult herman05
# esaoperations RayRodrigues4
# ESA_Rosetta VN0VAIS
# Philae2014 Evancuate
# m_gonzalezm m_gonzalezm
# endirectocon RAFALARA66
# Philae2014 Tomlxx
# Philae2014 Geoffr11
# esa MackBradley
# Philae2014 MajuKetchup
# _azizistanbul _azizistanbul
# bajan182 Its_sheddiyounG
# Goblinmerchant Thomas_W_J
# NewHorizons2015 kolcakharun
# BKrynah Its_sheddiyounG
# twitter grhluna25
# ESA_Rosetta Martian_Sam
# Philae2014 angelocanessa
# esaoperations shortcirkit
# sbestcellar derek_potkin
# NASA ryanmercer1
# ARTEde annienym11
# cnnbrk MashUpStanleyT
# khakhov sethzenz
# chrislintott conormansell
# BBCLookNorth UniLeedsPress
# margabult herman05
# itvcalendar UniLeedsPress
# Philae2014 sei_n
# Philae2014 Shachbabe
# Philae2014 sir_wernich
# Philae2014 jenjak24
# BBCRadioLeeds UniLeedsPress
# gmusser BlogdeLalo
# esa TheLovesLost
# ARTEfuture mcschindler
# ESA_Rosetta DrFumetts
# Reuters SoniaDevji
# ornikkar sAathenaAs
# Philae2014 iismoonman
# Independent JowDones
# NASA LewisWorrow
# esa esascience
# ESA_Rosetta sandtontimes
# ESA_Rosetta sandtondrive
# esascience brobof
# Philae2014 einfachbloggen
# Philae_MUPUS AAW_Darmstadt
# esa masanorimusic
# esa astro_luca
# esa sselinPaul
# AstroKatie nivnac
# davidjwbailey LancsMind
# EricKingNBC5 utarlington
# Philae2014 kamran_at
# Philae2014 HokieinSA
# BBC_HaveYourSay GrasmereAHT
# sirjmr welsh_hicks
# Philae2014 CaliforniaKara
# ESA_Rosetta NathalieHontele
# linaviol_ linaviol_
# ESA_Rosetta ungaman
# esa Kitty_B_Good
# sandysimcox gc_hurrell
# janvanasscheB FANSLABANDON
# esa christt
# ESA_Rosetta MackBradley
# Philae2014 VictorRijkaart
# Philae2014 mr_pac
# Philae2014 blasermillsProp
# timmermansr Brigitte_Ba
# timwithers Lester_Tiger
# BIS_spaceflight miely0199
# IliaVerrocchi FANSLABANDON
# ChristophDM ChristophDM
# Philae2014 andrespaolino
# ESA_Rosetta soulsuz
# esa FredNortier
# sirinpeccable MsWZ
# ESA_Rosetta angkasamalaysia
# Philae2014 BIS_spaceflight
# BBCBreaking Alfie_T_Scott
# CNES beweetch
# TSGTalks teemumaki
# Philae2014 spionchen
# Philae2014 Its_sheddiyounG
# linaviol_ linaviol_
# Philae2014 devilgas
# ESA_Rosetta lamontjp
# Philae2014 aramiggs
# eoportal MsWZ
# esaoperations Carlosrudu
# esa atomicxblue
# govertschilling grb090423
# OneMinuteBriefs alvo_muses
# peter5519toli juandiegosoler
# TimTierney marginal_error
# ErikaBTV emilymcmanamy
# rvaliantine Mivena
# ESA_Rosetta frostfang83
# Danske_ tbag5
# JuCollins Womble67
# teobesta teobesta
# LivUniAlumni captainlatte
# DavidBraben HelicityBoson
# xkcdComic CardinalXiminez
# Philae2014 GiolandaPap
# Philae2014 OriolPalenzuela
# astronewth M_Hammerstrom
# timmermansr ArwenSpain
# BBCBreaking Helena_Lee10
# woman_what sara_petrella
# Philae2014 MsWZ
# HuffPostUKTech beethakore
# Philae2014 MuddyHenry
# CraigLeeBurket CraigLeeBurket
# ESA_Rosetta kolcakharun
# Philae2014 dramaria
# ESA_Rosetta Liger
# esa_es JGALLEGOonfire
# Philae2014 andrewilley
# startup_people kevdurber
# esa FAnquilan
# Claire_Phipps NicHalley
# ESA_Rosetta EUROAVIA
# ESA_Rosetta mortizbey
# BBCRadio3 sarahhappydemon
# teobesta teobesta
# mashable Eharlemfilm
# Philae2014 theaelix
# ESA_Rosetta harlan_barker
# ddprieto Johnny_Quelado
# SocialMediaLond Opinions_Vary
# ESA_Rosetta WIRED_Germany
# WFLALeigh chadalittle
# Philae2014 TheCavac
# ESA_Rosetta anitagiam
# smalloy1 SnMalloy
# JakeHills O_PositiveBlood
# Jack_JL Rosemiddle
# Philae2014 Team_Toad
# PepeChambo _miguelmc
# Klom29 p_h_
# entranslation koeljong
# lithaen lithaen
# Philae2014 elis_cur
# Philae2014 LifeOnBaars
# kebap 4tuneQkie
# AhmedTheCat TrollULike
# Philae2014 isapinza
# ESA_Rosetta bencannon9
# britishmuseum HowJoeGod
# ESA_Rosetta doneill
# ESA_Rosetta 64bde
# BernaCan_ anti_UStA
# BBCBreaking DolphinComms
# mikeysmith THEJamesWhale
# Philae2014 cinteve
# Philae2014 KariniM_66
# esa inavonb
# Daily_Express jmreilly68
# ObservingSpace hermev
# Msuraev therealdjflux
# Philae2014 HusainHmd
# teobesta teobesta
# esascience AlexanderPutnik
# MetalArend MrEtnie
# LDMay projmgr
# teobesta teobesta
# ESA_Rosetta RAL_Space_STFC
# Philae2014 MarkWebb_DC
# esa tomislav_plazo
# EminCapa JeReenCe
# EpicCosmos ffloresm
# dlareo BlazdeDiego
# newburyastro Blackprojects
# ESA_Rosetta ffloresm
# TheNovaAgency CarolineHillDKC
# teobesta teobesta
# RainerKresken AAW_Darmstadt
# xkcdComic jjoseja
# maxplanckpress masanorimusic
# kazufukuda kittenblue0706
# OneMinuteBriefs JamesHWalker9
# Philae2014 brobof
# AlicesAstroInfo marginal_error
# nytimes lisablas
# NoorulAinur angkasamalaysia
# poweredbySAM BenJGlad
# teobesta teobesta
# Jeremy_Starship TrollULike
# elia_barcelo Nitrobencen0
# kumitaguchi Fowlhouses
# Philae2014 EdCostar
# thecraftmill thecraftmill
# AlicesAstroInfo marginal_error
# teobesta teobesta
# Philae2014 johnniemojo
# Philae2014 mr_skylord
# Philae2014 Nick_Ilic
# esaoperations chris_tibbs
# esa MinnieMach
# nchazarra elefenor
# SungrazerComets brainimpact
# Philae2014 isapinza
# RAGreeneCNN L4zick
# AboutTheBBC LinkPlugging
# asoundeffect cimarquez
# ESA_Rosetta 2m_marco
# ESA_Rosetta darrenmaule
# GarethJonesTV JeffSpangle
# Stirn DLR_de
# nchazarra elefenor
# LaurenMoorhouse RAGreeneCNN
# Philae2014 isapinza
# camillebordenet t0adscroak
# WSI_Bergamo jack_shillito
# barneyfarmer RossHaffenden
# kunstbiss kunstbiss
# Philae2014 _Amanda_n1
# BIS_spaceflight OberthMuseum
# tsartas_ napocornejo
# DrStuClark morten_pape
# MarilMontero viruvizzz
# esa TheLovesLost
# Philae2014 papinix71
# gpbasello gpbasello
# ESA_Rosetta jamesclay
# BarmyFry liam_groves
# parsonii masanorimusic
# Philae2014 isapinza
# nchazarra legeredemain
# alexekkelenkamp EZR_news
# firebox t0adscroak
# CNES MarieFaella
# karl_betz MGruenling
# newscientist LindsworthDeer
# guardianscience ruygatto
# AnaGalarraga1 AnaGalarraga1
# esa jack_shillito
# esa Obsoleteelec
# UKSEDS BIS_spaceflight
# el_pais matugar82
# Philae2014 ziggypao
# Sondas LuisTirado
# terakinizers mayuutann
# Philae2014 AshleyJYeager
# DLR_en CanberraDSN
# sen AAW_Darmstadt
# Wellard_Rumble Wellard_Rumble
# esa toktokalweer1ei
# esascience GpeGorm
# Paxi_ESAKids marginal_error
# kebap KirstenRulf
# Wellard_Rumble Wellard_Rumble
# ESA_Rosetta joachimreinhold
# ESA_Rosetta CelestiniaSpace
# tinowa AndreasSchepers
# aparanjape aparanjape
# SSlyper nixearle
# MissMontreal govertschilling
# esaoperations LJ_Pritchard
# mberzosa mberzosa
# simonroze guegoethe
# CTVOttMornLive marginal_error
# derHenrichs moethe
# Wellard_Rumble Wellard_Rumble
# esa AnaGalarraga1
# eonline marginal_error
# el_pais EstelaMaryCorbo
# AndreasSchepers ChrisManon
# esa SolveITTech
# Philae2014 MGMcgriskin
# disinformatico Fernando_IZ0EUI
# BBC_HaveYourSay zedzdead
# Philae2014 _Josh_the_white
# FabreMireille KarelU
# Wellard_Rumble Wellard_Rumble
# TheMarySue marginal_error
# esascience Polymathically
# Martynnorris ditasplaything
# FrancescoTop FrancescoTop
# ESA_Rosetta geoffmagill
# philipdundas Organicsoundsam
# maxplanckpress AAW_Darmstadt
# Wellard_Rumble Wellard_Rumble
# marginal_error marginal_error
# lucatbarone pepperpotmary
# ESA_Rosetta ekuulkers
# Philae2014 stewosch
# radio5_rne RadiactivoMan
# Domenclature falloutfits6070
# Sondas tsartas_
# divyabaji mystyle8804
# dmdarpizio BirthdaysFor
# SciQubed C_Coll89
# njoyard welikeyours4386
# EthanVonZamft HahMwah
# amdiazrivera anime3923
# MarkusZondler funnystuff3332
# Philae_MUPUS herrthees
# michelmaron michelmaron
# esa Badves
# MarkusZondler cookie_for
# dazmoriarty CyraHrn
# glovelace wakehurst2
# vilagz vilagz
# govertschilling DasITservices
# esparragosa1973 itgirl8053
# choitetsu Onl2forme2Envy
# dulcereyv FunniesLe
# zeitonline matthaeusfrost
# esa AmmadNaser
# ESA_Rosetta smale
# ESA_Rosetta B00matthews
# BlueCoatWalsall palfers45
# arjenkuiper lachlannl
# esyl_teop esyl_teop
# tvaldessolis FANSLABANDON
# Philae2014 imranganath
# ObservingSpace Gamebloggar
# lagamez FANSLABANDON
# jf_moreno AmigosIng
# esa BobBeeke
# newscientist hannahcaddick
# soheilr7 soheilr7
# HuffPostUKTech ProfessorOM
# IDGse esyl_teop
# esascience einfachbloggen
# nancywalshcbc _Merlyn
# newscientist Sunite
# ESA_Rosetta axecold
# AbortedNews office00344401
# esyl_teop esyl_teop
# Rickvkalker chrisopdeweegh
# esa Brainman365
# ESA_Rosetta Thinkintellect
# ESA_Rosetta jabez_azariah
# PeoplesAstro DamWev
# 7takeuchi7 mayuutann
# esa masanorimusic
# esa SaddiaLarsson
# nchazarra legeredemain
# futurasciences NadegeJoly
# DrBrianMay WellsiteGeo
# NickAstronomer SalAstroSoc
# legeredemain legeredemain
# ESA_Rosetta spreentDotCom
# nationaltrust nationaltrust
# Killian_Bou Juliette_Heb
# _Bryony_ Tarante11a
# joaoacj joaoacj
# ProfBrianCox ImTracyWilliams
# controladores PepJordana
# nationaltrust nationaltrust
# esa_es lithospheric
# ESA_Rosetta iambinaxx
# ESA_Rosetta joaoacj
# Tina_Ibsen nsentse
# BBCWorld anxiousjimmy
# nationaltrust Silverstrange
# ewnupdates clvandiemen
# paola_saluzzi sirgolly
# BBCStargazing becky1505
# TomChivers ruthie147
# astrodicticum franzlindinger
# Jillian_Scudder marginal_error
# ESA_de Sunufatarungo
# annachifor SerieA100
# HollyACave Womble67
# maxplanckpress marginal_error
# ESA_Rosetta Eifelralf
# MarJMendano MarJMendano
# ArabellaSock simiansuter
# emenietti annachifor
# JBoscher210 kitfisto68
# Philae2014 EdwinaSesto
# DjChiamaItalia Fernando_IZ0EUI
# Philae2014 alldatjas
# ESA_Rosetta SinoDefence
# OfficialSanta MuddyRiverGal
# chrisenorth SalAstroSoc
# esa HowItWorksmag
# rtve ByChanchi
# Shakes_Today OptimoPrincipi
# CoderDojoMgar ScienceWeek
# hitch_daniel hitch_daniel
# IsambardsLad IsambardsLad
# infomorning murdomesser
# Philae2014 StefanoScutti
# SungrazerComets Darka2000
# nationaltrust nationaltrust
# BBCWorld anakatehey
# revistamongolia elefanteensalon
# NidhalGuessoum ABOMEHSN
# esa huwmjames
# BillHarvey2 IsambardsLad
# BBC_HaveYourSay jensonfan1983
# ESA_Rosetta vincewwalker
# NickGurney tellahtruth
# aryelio aryelio
# Spacettf Cienctec1
# Pseudokalypse philodem
# DrAliceRoberts andy1702
# Philae2014 PepJordana
# ESA_Italia Manu_Duff
# ESA_Rosetta imagine_Linda
# timmermansr RodRossSA
# NidhalGuessoum ABOMEHSN
# RodRossSA timmermansr
# susankitchens dufussy
# Philae2014 Justice30
# ESA_Rosetta JohnPaul_OD
# ESA_Rosetta Eddiemackle
# ESA_Rosetta eddyproca
# ESA_Rosetta joypamnani
# ESA_Rosetta cathebass
# SungrazerComets AAW_Darmstadt
# AlicesAstroInfo marginal_error
# Greenfaery snakenuts
# dDonnell25 BenLangmaid
# Philae2014 nuwie101
# ESA_Rosetta MEEDIA
# AstroKatie Paleo_Bonegirl
# ESA_Rosetta mandiekemp
# ruthie147 stevemacken
# ESA_Rosetta ScaryItalian
# Markotron snakenuts
# ANNBELLE2015257 ANNBELLE2015257
# jhillers sarahashash
# ScientificScott HeidiKneale
# momado_50 HerrFunk
# Philae2014 ZacherMartin
# BBCNews sidbishnoi
# ESA_Rosetta PxlPhile
# nchazarra elefenor
# arielwaldman toktokalweer1ei
# ESA_Rosetta DrChris_Walker
# Philae_Ptolemy RosettaInTheUK
# ReutersAero WOLKEFN
# Anycas IreneUrbina
# ESA_Rosetta DavidAtkinson00
# interplanetary IanARegan
# ObservingSpace BrosgillOptics
# ESA_Rosetta KHesser
# johopkins27 FurzeyRetriever
# jjblasvegas susankitchens
# GUI_UVa turnip_GUI
# ANWBverkeer rvhaarle
# okarol DiyaMarketing
# Philae2014 M_Hammerstrom
# Citibank suznuss
# Philae2014 dayjn
# elakdawalla indophilia
# Philae2014 kentnottheband
# _meyse_ _meyse_
# aparanjape Meetasengupta
# esa AlbertoBGomez
# DLR_next TheCocoaNaut
# Philae2014 Turkandt
# OberthMuseum OberthMuseum
# youpunt youpunt
# esa rajas_godbole
# Citibank suznuss
# esa MeReachingout
# indophilia elakdawalla
# cnnbrk xiaojbm
# Cla_dG OrlandinaB
# ottaviofogliata PBrock
# esaoperations fjgz3
# esa rajas_godbole
# Eddieonfox SKIPdaZIP
# esa MouradHamdouche
# PhilCoffey GabrieleSteen
# esaoperations BillThomson17
# thenicolabryant marginal_error
# SungrazerComets Gamebloggar
# 5FM developspacesa
# MikeAR_ MikeAR_
# okarol DiyaMarketing
# Irreductible Nitrobencen0
# Philae2014 latente_flickr
# Philae2014 upsidedowndog
# jorge_trevin javidelaviuda
# cristina_pardo RodolfoMandrika
# astroforfun AstroExeter
# erikakcarlson erikakcarlson
# DiyaMarketing okarol
# Philae2014 NatGeoTvItalia
# Markotron snakenuts
# saruman___ duke_de
# CelestiniaSpace CelestiniaSpace
# joelwmparker RajuKhagram
# ads_infinitum Ilona_
# fasyibrahim susankitchens
# ARTEfuture geigerpiero
# trendinaliaBE joezorry
# jjsaenzde migusant
# Philae2014 johnantoni
# MikeAR_ MikeAR_
# esaoperations janet_t_55
# gpbasello gpbasello
# cnni bachatero1979
# Philae2014 PlanetarioMad
# ESA_Rosetta fabriziolab
# Philae_MUPUS marginal_error
# Philae2014 kmdk
# Philae2014 yonko33
# ESA_Rosetta breeze_crow
# chicolateiro mjoaonascimento
# Philae_MUPUS digitalmeteo
# Markotron snakenuts
# Astro_Florian ArnaudVicari
# ESA_Rosetta EstrategiaPI
# JosephJBroni NickGurney
# ESA_Rosetta sri_barath
# habimaru habimaru
# Philae2014 MarieNinaah
# GaiaUB GaiaUB
# Sammiej1987 tweet_ergo_sum
# DiyaMarketing okarol
# Philae2014 danielhardegger
# DjChiamaItalia Fernando_IZ0EUI
# ESA_Rosetta ZaggyLu
# bergopolis marginal_error
# PeoplesAstro dazzydazzler99
# MarloesvdLaan michieljonkman
# BrianSoule JohnHedge
# PhysicsHenry diegosoulreaver
# govertschilling wdejager
# SandalPress charmarvel
# Rubee100 DiyaMarketing
# ESA_Rosetta CedricNET
# davidshukmanbbc yarwell
# hiergiltdiestfu sternwarte_hann
# ESA_Rosetta Stevotonin
# BrookSci BrookSci
# CNNLightYears JohnFredClark
# wfaaweathertoo MetLaugh
# Philae2014 frogmller
# ESA_Rosetta LeTof73
# Philae_MUPUS thelightinlife
# fredwillie460 fredwillie460
# timmermansr jamesf40
# BBCBreaking echieLIA
# Univ_Orleans Univ_Orleans
# Philae2014 appolomustdie
# ESA_Rosetta PhilHobson2
# Philae2014 MartinST81
# Philae2014 brassshadow
# IsUniverse ErYogendraSingh
# sternwarte_hann hiergiltdiestfu
# DobsonJan Boeufblogginon
# ESA_Rosetta jamesf40
# esa astronomiacecc
# Penny4NASA1 Penny4NASA1
# Philae2014 ADGAGroup
# NASA kpcuk
# ESA_Rosetta petrimp
# Chad_DJCudi shotCALLER187
# Naukas_com mfherrador
# Philae2014 QUBAlumni
# Philae2014 denwalt
# MarJMendano fjsevilla
# ESA_Rosetta joachimreinhold
# snitchsandy kennethmosop
# NEOShieldTeam timmermansr
# esaoperations stevieacko
# esa Robinhood_68
# acanasvargas PepJordana
# ESA_Rosetta michal_ostasz
# esa seeit_wantit
# SkyNewsBreak MikeAR_
# Philae2014 cosmojules
# el_pais matugar82
# Madabip velopilot
# ESA_Rosetta leovanderheide
# ESA_Rosetta DHallegraeff
# BIS_spaceflight BIS_spaceflight
# Philae2014 betlagal
# Philae2014 SalopianJacob
# Philae2014 kmdk
# BBCBreaking BritishMensa
# G_Salanitro SerieA100
# elakdawalla dazzydazzler99
# hoyenmadrid javierarmentia
# ESA_Rosetta ImTracyWilliams
# ESA_Rosetta CancelTab
# kennethmosop snitchsandy
# GappistanRadio balanced_tarazu
# esaoperations rdrimmel
# icey_mark jimmcquaid
# GuusRoeselers GuusRoeselers
# ESA_Rosetta All_For_Free
# ESA_Rosetta Barrist
# govertschilling puffeltje
# esaoperations AnneCalie
# Philae2014 angkasamalaysia
# ESA_Rosetta tanyanghan
# ESA_de rheinzeitung
# FacultiMedia BritishMensa
# esa iambinaxx
# ESA_Rosetta didierverna
# ESA_Rosetta JulioMiravalls
# willsmith tellahtruth
# Philae2014 NatGeoTvItalia
# esa Wellard_Rumble
# esa Toadfish007
# ESA_Rosetta Step_981
# ESA_Rosetta johnniemojo
# ESA_Rosetta BeeM001
# esa xdesig
# esaoperations SparkyDaveUK
# Der_Postillon gernot_t
# Philae2014 denebofficial
# esa ESA_fr
# DeDee_06 bluenumeral
# emilysmart17 LaraLlama1
# esa craigiw
# Philae2014 jasperdebock
# ESA_Rosetta dominiqueleglu
# astrojenny Brendano
# DiyaMarketing Rubee100
# megschwamb ogeerunner
# Carlhopkins Carlhopkins
# danielscuka adamcorrie
# ESA_Rosetta ludvik264
# AstroGingerSnap marginal_error
# KerbalSpaceP eric_lobdell
# AstroKatie _Nosila_
# HCross2012 mashedbannana
# JumpMag Haringey6thForm
# Philae2014 sajeffe
# ESA_Rosetta Paleo_Bonegirl
# Philae2014 MileHighFlyGuy
# ESA_Rosetta CelestiniaSpace
# Philae2014 ArnaudDevelay
# RAeSTimR sUASnews
# Jackyflatter _adeliadeli
# investiganonimo NagyNellbrack
# purplefroglet whereisyvette
# charlieowen4 arrayson
# ESA_Rosetta drfarres
# verge cocoy
# BBCBreaking Del_Alpha

# %%
# retweet_list = retweet_only_df['text'].apply(lambda x: x.split(":")[0][2:]) # slice and split to get retweet users

retweet_network = nx.Graph()
seenNodes_retweet = set()


for index, row in retweet_only_df.iterrows():
    node_1 = row["from_user"]
    if node_1 not in seenNodes_retweet and node_1 is not None:
        retweet_network.add_node(node_1)
        seenNodes_retweet.add(node_1)
    
    ent_load = json.loads(row["entities_str"]) #load the entities_str as a json
    node_2 = ent_load["user_mentions"][0]["screen_name"] # grab the first mention which is the retweet
    if node_2 not in seenNodes_retweet and node_2 is not None:
        retweet_network.add_node(node_2)
        seenNodes_retweet.add(node_2)
    
    retweet_network.add_edge(node_1,node_2)

# %%
mentions_network = nx.Graph()
seenNodes_mentions = set()

for index, row in df.iterrows():
    
    node_1 = row["from_user"]
    if node_1 not in seenNodes_mentions and node_1 is not None:
        mentions_network.add_node(node_1)
        seenNodes_mentions.add(node_1)
        
    node_2 = row["text"]
    match = re.search("@[A-Za-z0-9_]* ", node_2)
    if match:
        if match.group() not in seenNodes_mentions and match.group() is not None:
            mentions_network.add_node(match.group())
            seenNodes_mentions.add(match.group())
        
        if match.group() == "@EUCouncil":
            print(match.group())
            
        mentions_network.add_edge(node_1,match.group())

# %%
# https://stackoverflow.com/questions/17381006/large-graph-visualization-with-python-and-networkx
def save_graph(graph,file_name):
    #initialze Figure
    plt.figure(num=None, figsize=(800,800), dpi=80)
    plt.axis('off')
    fig = plt.figure(1)
    pos = nx.spring_layout(graph)
    nx.draw_networkx_nodes(graph,pos)
    nx.draw_networkx_edges(graph,pos, edge_color="r")
    nx.draw_networkx_labels(graph,pos)

    cut = 1.00
    xmax = cut * max(xx for xx, yy in pos.values())
    ymax = cut * max(yy for xx, yy in pos.values())
    plt.xlim(-1*xmax, xmax)
    plt.ylim(-1*ymax, ymax)

    plt.savefig(file_name)
    pylab.close()
    del fig
    
# save_graph(replies_network,"../images/replies_network.pdf")
# save_graph(retweet_network,"../images/retweet_network.pdf")
# save_graph(mentions_network,"../images/mentions_network.pdf")

# %%
date_raw2 = df

# %%
day = date_raw2.set_index('created_at').groupby(pd.Grouper(freq='D'))

# %%
day_labels = [str(ts.strftime("%d/%m"))
               for ts in day.count()["id_str"].index.tolist()]


day_data = day.count()["id_str"].tolist()

# %%
#https://stackoverflow.com/questions/332289/how-do-you-change-the-size-of-figures-drawn-with-matplotlib
y = day_data
x = day_labels

plt.rcParams["figure.figsize"] = (20,30)

plt.title("CometLanding timeline")
plt.xlabel("Day")
plt.ylabel("Tweets")


plt.plot(x, y)
plt.show()

# %%
plt.rcParams["figure.figsize"] = (5,5)
gg.createTweetsTypeChart(df)
plt.show()
plt.clf()

# %%
gg.createActiveDayTimelinePlot(df)
plt.show()
plt.clf()

# %%
gg.createApplicationChart(df)
plt.show()
plt.clf()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9220/1503395352.py in <module>
# ----> 1 gg.createApplicationChart(df)
#       2 plt.show()
#       3 plt.clf()
#
# c:\Users\thoma\OneDrive\Desktop\Year 2\Semester 2\CS2006\PPractical\CS2006P\notebooks\../code\generateGraphs.py in createApplicationChart(df)
#     107
#     108     y_pos = label
# --> 109     ax.barh(y_pos, data, align='center')
#     110     ax.set_yticks(y_pos, labels=label)
#     111     ax.invert_yaxis()
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in wrapper(self, *args, **kwargs)
#      71
#      72         def wrapper(self, *args, **kwargs):
# ---> 73             return get_method(self)(*args, **kwargs)
#      74
#      75         wrapper.__module__ = owner.__module__
#
# TypeError: set_ticks() got an unexpected keyword argument 'labels'

# %%
gg.createHashtagChart("../data/CometLandingFixed.json")
plt.show()
plt.clf()
# Out:
# ../code/generateGraphs.py:165: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Frequency'][index] += 1

# %%
gg.createWordCloud(gg.getListOfAllHashTags("../data/CometLandingFixed.json"))
plt.show()
plt.clf()

# %% [markdown]
# For the analysis of the most popular hashtags used, we decided to exclude "CometLanding" of any case as all tweets in the dataset should have this hashtag which will automatically make it the most popular hashtag.  As shown in the word cloud, the top 3 most popular hastags are "67P", "Rosetta" and "Philae".

# %%
gg.createDailyTimelinePlot(df)
plt.show()
plt.clf()

# %%
# in_reply_to_user_id_str
reply_no = len(total_replies)

# %%
replied_users = set(total_replies["in_reply_to_user_id_str"]) # set of users receiving a reply
all_users = set(df["from_user_id_str"]).union(replied_users) # set of users that either sent/reply/retweet a tweet or received a reply
normal_with_reply_users = set(df["from_user_id_str"]).intersection(replied_users)
print("Average number of reply received by each user: " + str(len(total_replies) / len(all_users)))
print("Average number of reply received by each replied user: " + str(len(total_replies)/len(replied_users)))
# Out:
# Average number of reply received by each user: 0.03408731414109459
# Average number of reply received by each replied user: 2.1576971214017524

# %%
print("Number of users received reply: " + str(len(replied_users)))
print("Number of users who tweet/reply/retweet: " + str(len(set(df["from_user_id_str"]))))
print("Number of users either send/reply/retweet or received a reply: " + str(len(all_users)))
# Out:
# Number of users received reply: 799
# Number of users who tweet/reply/retweet: 50216
# Number of users either send/reply/retweet or received a reply: 50576

# %%
# get replies that are to users that have also tweeted/replied/retweeted
replies_to_from_users = total_replies[total_replies["in_reply_to_user_id_str"].isin(set(df["from_user_id_str"]))]
print("Average number of reply received by each user that has also tweeted/replied/retweeted: "
     + str(len(replies_to_from_users)/len(set(df["from_user_id_str"]))))
# Out:
# Average number of reply received by each user that has also tweeted/replied/retweeted: 0.026186872709893262

# %%
# %matplotlib 
#data
date_list_raw = [str(ts.strftime("%Y-%m-%d"))for ts in day.count()["id_str"].index.tolist()]
date_list = [] # Dates with tweets
date_data_list = []
date_label_list = []

for d in date_list_raw:
    date_raw = df[df['created_at'].apply(lambda x: True if re.search('^'+d, str(x)) else False)]
    date = date_raw.set_index('created_at').groupby(pd.Grouper(freq='H'))
    date_labels = [str(ts.strftime("%H"))for ts in date.count()["id_str"].index.tolist()]
    date_data = date.count()["id_str"].tolist()
    
    if(len(date_data) > 0 ):
        date_list.append(d) # append dates that contains tweets
        date_data_list.append(date_data)
        date_label_list.append(date_labels)



#graph
fig, ax = plt.subplots()
plt.subplots_adjust(bottom=0.2)
l, = plt.plot(date_label_list[0], date_data_list[0], lw=2)

class Index:
    
    def __init__(self):
        self.i = 0
        self.draw_graph()

    def next(self, event):
        self.i = (self.i + 1) % len(date_list)
        self.draw_graph()
  
        
            
    def prev(self, event):
        self.i -= 1
        if(self.i == -1): 
            self.i= len(date_list)-1
        self.draw_graph()
    
    def draw_graph(self):
        
        plt.clf()
        plt.title("CometLanding timeline " + date_list[self.i])
        plt.xlabel("Hour")
        plt.ylabel("Tweets")
        plt.plot(date_label_list[self.i], date_data_list[self.i])
        plt.draw()
        
        
       
        axprev = plt.axes([0.7, 0.05, 0.1, 0.075])  #Button position
        axnext = plt.axes([0.81, 0.05, 0.1, 0.075]) #Button position
        self.bnext = Button(axnext, 'Next') 
        self.bnext.on_clicked(self.next)
        self.bprev = Button(axprev, 'Previous')
        self.bprev.on_clicked(self.prev)
        
        
        

Index()
plt.show()

# %%
# takes a few minutes to complete

# get retweets
retweets = df[df['text'].apply(
    lambda x: True if re.search("^RT @.*", x) else False)]

retweeted_user = dict() # key = user_id, value = no. being retweeted
with open('../data/CometLandingFixed.json', 'r', encoding="utf8") as json_file:
        json_load = json.load(json_file)
        print (len(json_load))
        
        # check entities_str for each tweet
        for x in range(len(json_load)):
            # if current checked entities_str belongs to a retweet
            if (x in retweets.index):
                user = json_load[x]["user_mentions"][0]["id_str"] # get user id
                cur_rt = retweeted_user.setdefault(user, 0) # get recorded no. user being retweeted
                retweeted_user.update({user: cur_rt + 1}) # update no. user being retweeted
                
                # break loop if already reached last retweet
                if (x == max(retweets.index)):
                    break
            else:
                continue
        
json_file.close()

from_user = set(df["from_user_id_str"]) # set of unique id of from_users
# no. of users that are either retweeted or have tweeted/retweeted/replied
all_users_with_rt = len(from_user.union(retweeted_user.keys())) 
# https://www.datacamp.com/community/tutorials/python-dictionary-comprehension
# users that are retweeted and have tweeted/retweeted/replied with no. being retweeted
retweeted_from_user = {user: rt for (user, rt) in retweeted_user.items() if user in set(df["from_user_id_str"])}
# Out:
# 77307

# %%
print("Average no. each retweeted user being retweeted: " + str(len(retweets)/len(retweeted_user)))
print("Average no. each user being retweeted: " + str(len(retweets)/all_users_with_rt))
print("Average no. each user that has tweeted/retweeted/replied being retweeted: " + 
     str(sum(retweeted_from_user.values()) / len(from_user)))

# %%
print("No. of retweets: " + str(len(retweets)))
print("No. of retweets where retweeted user has tweeted/retweeted/replied: " + str(sum(retweeted_from_user.values())))
print("No. of users being retweeted: " + str(len(retweeted_user)))
print("No. of users that are either tweeted or has tweeted/retweeted/replied: " + str(all_users_with_rt))
print("No. of users that are tweeted and has tweeted/retweeted/replied: " + str(len(retweeted_from_user)))

# %%
retweet_reply = total_replies[total_replies['text'].apply(lambda x: True if re.search("^RT @.*",x) else False)]

# %%
len(retweet_reply)

# %%
# %matplotlib inline
